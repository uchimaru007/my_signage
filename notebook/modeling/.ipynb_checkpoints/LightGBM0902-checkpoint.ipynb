# %%
import pandas as pd
import numpy as np

import ruptures as rpt
from ruptures.metrics import precision_recall
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

import lightgbm as lgb
import seaborn as sns

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [12, 9]

# %%
df = pd.read_csv('/Users/estyle-150/github/my_signage/data/processed/processed20240826.csv')
df['datetime'] = pd.to_datetime(df['datetime'])
df.set_index('datetime', inplace=True)

df.drop(['price_am_moving_avg_7', 'price_am_moving_avg_30', 'price_pm_moving_avg_7', 'price_pm_moving_avg_30', 'day'], axis=1, inplace=True)

################
### 変化点検知 ###
################

# コスト関数の設定
model = "l2"
# アルゴの設定と学習
algo = rpt.Dynp(model=model).fit(df[['y']])
# 変化点の検出
my_bkps = algo.predict(n_bkps=3)
# 結果のプロット
rpt.show.display(df[['y']], my_bkps, figsize=(12, 9))
plt.show()
# 検出された変化点
print(my_bkps)

# 訓練データをとる
train_data = df[df['is_train'] == 1].copy()

# テストデータをとる
test_data = df[df['is_train'] == 0].copy()

# 訓練データから不要な列（'is_train'）を削除
train_data.drop(['is_train'], axis=1, inplace=True)

# テストデータから不要な列を削除
test_data.drop(['y','is_train'], axis=1, inplace=True)

# テストデータからcloseを削除（このデータで予測する）
test_data_open = test_data.drop(['close'], axis=1, inplace=False)

display(train_data.head(), test_data.head())


plt.plot(df['y'])
# Out:
# [600, 2060, 2100, 2466]
#              y  client  close  price_am  price_pm     price  year  month  \
# datetime
# 2010-07-01  17       0      0  0.192308  0.076923  0.134615  2010      7
# 2010-07-02  18       0      0  0.692308  0.423077  0.557692  2010      7
# 2010-07-03  20       0      0  1.807692  1.192308  1.500000  2010      7
# 2010-07-04  20       0      0  1.407407  0.925926  1.166667  2010      7
# 2010-07-05  14       0      0  0.346154  0.192308  0.269231  2010      7
#
#             weekday  y_lag_365  price_am_lag_1  price_am_lag_7  \
# datetime
# 2010-07-01        3        NaN             NaN             NaN
# 2010-07-02        4        NaN        0.192308             NaN
# 2010-07-03        5        NaN        0.692308             NaN
# 2010-07-04        6        NaN        1.807692             NaN
# 2010-07-05        0        NaN        1.407407             NaN
#
#             price_am_lag_365  price_pm_lag_1  price_pm_lag_7  price_pm_lag_365
# datetime
# 2010-07-01               NaN             NaN             NaN               NaN
# 2010-07-02               NaN        0.076923             NaN               NaN
# 2010-07-03               NaN        0.423077             NaN               NaN
# 2010-07-04               NaN        1.192308             NaN               NaN
# 2010-07-05               NaN        0.925926             NaN               NaN
#             client  close  price_am  price_pm  price  year  month  weekday  \
# datetime
# 2016-04-01       1      0       3.0       2.0    2.5  2016      4        4
# 2016-04-02       0      0       5.0       5.0    5.0  2016      4        5
# 2016-04-03       1      0       2.0       2.0    2.0  2016      4        6
# 2016-04-04       1      0       1.0       1.0    1.0  2016      4        0
# 2016-04-05       0      0       1.0       1.0    1.0  2016      4        1
#
#             y_lag_365  price_am_lag_1  price_am_lag_7  price_am_lag_365  \
# datetime
# 2016-04-01       60.0             5.0             4.0               2.0
# 2016-04-02       75.0             3.0             5.0               2.0
# 2016-04-03       86.0             5.0             5.0               4.0
# 2016-04-04       69.0             2.0             4.0               2.0
# 2016-04-05       61.0             1.0             4.0               1.0
#
#             price_pm_lag_1  price_pm_lag_7  price_pm_lag_365
# datetime
# 2016-04-01             4.0             5.0               2.0
# 2016-04-02             2.0             5.0               1.0
# 2016-04-03             5.0             4.0               3.0
# 2016-04-04             2.0             4.0               2.0
# 2016-04-05             1.0             4.0               1.0

# %%
# 訓練データから閉店時のデータを削除（これを学習させる）
train_data_open =  train_data[train_data['close']==0]
train_data_open_2 = train_data_open.drop(['close'], axis=1, inplace=False)

print(len(train_data_open_2))
print(len(train_data))
# Out:
# 2074
# 2101

# %%
from sklearn.model_selection import KFold
import optuna.integration.lightgbm as lgb_op
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error

# 訓練データと検証データに分ける
N = 365
X_train = train_data_open_2.drop(['y'], axis=1)[:-N]
y_train = train_data_open_2['y'][:-N]

X_test = train_data_open_2.drop(['y'], axis=1)[-N:]
y_test = train_data_open_2['y'][-N:]

# LightGBM用のデータセット
lgb_train = lgb.Dataset(X_train, y_train)
lgb_test = lgb.Dataset(X_test, y_test)

# 評価基準 
params = {"objective" : "regression", 
              "metric" : "mse", 
              "num_leaves" : 7,
              "early_stopping_rounds" : 50,
              "verbosity": -1}

# 回帰モデル作成
model = lgb.train(params, lgb_train, valid_sets=lgb_test)

# 予測
test_pred = model.predict(X_test)
pred_df = pd.concat([y_test.reset_index(drop=True), pd.Series(test_pred)], axis = 1)
pred_df.columns = ['true', 'pred']
pred_df

rmse = np.sqrt(mean_squared_error(y_test, test_pred))
print('RMSE:',round(rmse,3))
# Out:
# RMSE: 9.796

# %%
importances = model.feature_importance(importance_type='gain')
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(8,4))
plt.title('feature importance')
plt.bar(range(len(indices)), importances[indices])
plt.xticks(range(len(indices)), train_data_open_2.columns[indices], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x158cd8380>,
#   <matplotlib.axis.XTick at 0x158e8e510>,
#   <matplotlib.axis.XTick at 0x1590b2b40>,
#   <matplotlib.axis.XTick at 0x158e6e5d0>,
#   <matplotlib.axis.XTick at 0x1580498e0>,
#   <matplotlib.axis.XTick at 0x159e3d4f0>,
#   <matplotlib.axis.XTick at 0x159e3d820>,
#   <matplotlib.axis.XTick at 0x159e3d9a0>,
#   <matplotlib.axis.XTick at 0x159d81400>,
#   <matplotlib.axis.XTick at 0x159d90e00>,
#   <matplotlib.axis.XTick at 0x159d91610>,
#   <matplotlib.axis.XTick at 0x159e4cfe0>,
#   <matplotlib.axis.XTick at 0x159e4e150>,
#   <matplotlib.axis.XTick at 0x158e6f830>],
#  [Text(0, 0, 'weekday'),
#   Text(1, 0, 'price'),
#   Text(2, 0, 'client'),
#   Text(3, 0, 'price_pm'),
#   Text(4, 0, 'price_pm_lag_7'),
#   Text(5, 0, 'year'),
#   Text(6, 0, 'month'),
#   Text(7, 0, 'price_am'),
#   Text(8, 0, 'price_am_lag_365'),
#   Text(9, 0, 'price_am_lag_7'),
#   Text(10, 0, 'price_am_lag_1'),
#   Text(11, 0, 'y_lag_365'),
#   Text(12, 0, 'price_pm_lag_1'),
#   Text(13, 0, 'y')])

# %%
# 可視化
plt.plot(pred_df)
# Out:
# [<matplotlib.lines.Line2D at 0x159f22630>,
#  <matplotlib.lines.Line2D at 0x157ffa9f0>]

# %%
# oputunaによるハイパーパラメータのチューニング
import optuna

# %%
x_tr = X_train
x_va = X_test
y_tr = y_train
y_va = y_test

# %%
# 固定値のハイパーパラメータ
params_base = {
    'objective' : 'regression',
    'metrics' : 'mse',
    'random_seed' : 123,    
    'learnig_rate' : 0.1,  # １回のブースティングで加算する重みの比率
    'min_data_in_bin' : 3,  # ヒストグラムの１つのbinに含まれる最小のレコード数
    'bagging_freq' : 0,
    'verbose' : -1,
}


# ハイパーパラメータの探索範囲
def objective(trial):
    params_turning = {
        'num_leaves' : trial.suggest_int('num_leaves', 50, 200),
        'min_data_in_leaf' : trial.suggest_int('min_data_in_leaf', 2, 30),
        'max_bins' : trial.suggest_int('max_bin', 200, 400),
        'bagging_fraction' : trial.suggest_float('bagging_fraction', 0.8, 0.95),
        'feature_fraction' : trial.suggest_float('eature_fraction', 0.35, 0.65),
        'min_gain_to_split' : trial.suggest_float('min_gain_to_split', 0.01, 1, log=True),
        'lambda_11' : trial.suggest_float('lambda_11', 0.01, 1, log=True),
        'lambda_12' : trial.suggest_float('lambda_12', 0.01, 1, log=True),
    }
    
    # 探索用ハイパーパラメータの設定
    params_turning.update(params_base)
    lgb_train = lgb.Dataset(x_tr, y_tr)
    lgb_eval = lgb.Dataset(x_va, y_va)

    #探索用ハイパーパラメータで学習
    model = lgb.train(params_turning,
                      lgb_train,
                      num_boost_round=6000,
                      valid_sets=[lgb_train, lgb_eval],
                      valid_names=['train', 'valid'],
                      callbacks=[lgb.early_stopping(50),
                                 lgb.log_evaluation(500)])
    y_va_pred = model.predict(x_va,
                              num_iteration=model.best_iteration)
    score = mean_absolute_error(y_va, y_va_pred)
    print('')
    return score

# %%
# ハイパーパラメータの最適化の実行
study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=0), direction='minimize')
study.optimize(objective, n_trials=1500)
# Out:
# [I 2024-09-03 08:43:09,693] A new study created in memory with name: no-name-fc38df8f-5821-402e-ae32-52517160381a
# [I 2024-09-03 08:43:09,786] Trial 0 finished with value: 8.081173220276684 and parameters: {'num_leaves': 132, 'min_data_in_leaf': 22, 'max_bin': 321, 'bagging_fraction': 0.8817324774495345, 'eature_fraction': 0.47709643980167143, 'min_gain_to_split': 0.19578897201212997, 'lambda_11': 0.07501954443620121, 'lambda_12': 0.6074996073425692}. Best is trial 0 with value: 8.081173220276684.
# [I 2024-09-03 08:43:09,874] Trial 1 finished with value: 8.02534174416582 and parameters: {'num_leaves': 195, 'min_data_in_leaf': 13, 'max_bin': 359, 'bagging_fraction': 0.8793342379629356, 'eature_fraction': 0.5204133683281797, 'min_gain_to_split': 0.70989362574059, 'lambda_11': 0.013869861245357327, 'lambda_12': 0.014936835544198456}. Best is trial 1 with value: 8.02534174416582.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	train's l2: 24.8131	valid's l2: 103.428
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	train's l2: 19.5619	valid's l2: 103.038
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:09,961] Trial 2 finished with value: 7.973338537864289 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 26, 'max_bin': 356, 'bagging_fraction': 0.9305018222370228, 'eature_fraction': 0.6435855026698292, 'min_gain_to_split': 0.3965675081771009, 'lambda_11': 0.08374496868436809, 'lambda_12': 0.36396393567863894}. Best is trial 2 with value: 7.973338537864289.
# [I 2024-09-03 08:43:10,069] Trial 3 finished with value: 8.02816496915885 and parameters: {'num_leaves': 67, 'min_data_in_leaf': 20, 'max_bin': 228, 'bagging_fraction': 0.9417003375574375, 'eature_fraction': 0.5065544965250215, 'min_gain_to_split': 0.06750312521595925, 'lambda_11': 0.0338151426782029, 'lambda_12': 0.35356346291488117}. Best is trial 2 with value: 7.973338537864289.
# [I 2024-09-03 08:43:10,157] Trial 4 finished with value: 8.158552127828226 and parameters: {'num_leaves': 118, 'min_data_in_leaf': 18, 'max_bin': 203, 'bagging_fraction': 0.8926453245613816, 'eature_fraction': 0.5336287168167264, 'min_gain_to_split': 0.17134364197119656, 'lambda_11': 0.7717846862118064, 'lambda_12': 0.2310152225018237}. Best is trial 2 with value: 7.973338537864289.
# Early stopping, best iteration is:
# [86]	train's l2: 23.0849	valid's l2: 100.799
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [133]	train's l2: 16.6272	valid's l2: 101.854
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	train's l2: 19.6054	valid's l2: 106.109
# [I 2024-09-03 08:43:10,255] Trial 5 finished with value: 8.22378363113184 and parameters: {'num_leaves': 104, 'min_data_in_leaf': 14, 'max_bin': 340, 'bagging_fraction': 0.8090338207443906, 'eature_fraction': 0.5500300146337003, 'min_gain_to_split': 0.21941976179005757, 'lambda_11': 0.02634905974115613, 'lambda_12': 0.018107254066631072}. Best is trial 2 with value: 7.973338537864289.
# [I 2024-09-03 08:43:10,356] Trial 6 finished with value: 8.14482316996317 and parameters: {'num_leaves': 97, 'min_data_in_leaf': 12, 'max_bin': 314, 'bagging_fraction': 0.865790227019348, 'eature_fraction': 0.6465121514177679, 'min_gain_to_split': 0.015998881492631498, 'lambda_11': 0.02616697456085447, 'lambda_12': 0.021019338091154416}. Best is trial 2 with value: 7.973338537864289.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [56]	train's l2: 19.6454	valid's l2: 107.279
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	train's l2: 16.6003	valid's l2: 104.104
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:10,485] Trial 7 finished with value: 8.039008562249146 and parameters: {'num_leaves': 148, 'min_data_in_leaf': 9, 'max_bin': 293, 'bagging_fraction': 0.8366638388002404, 'eature_fraction': 0.3976908750936559, 'min_gain_to_split': 0.016624564693643644, 'lambda_11': 0.2054277828628595, 'lambda_12': 0.018895826938026012}. Best is trial 2 with value: 7.973338537864289.
# [I 2024-09-03 08:43:10,561] Trial 8 finished with value: 8.186822372382528 and parameters: {'num_leaves': 79, 'min_data_in_leaf': 12, 'max_bin': 365, 'bagging_fraction': 0.8145651913689592, 'eature_fraction': 0.6013834722496412, 'min_gain_to_split': 0.015566709318481201, 'lambda_11': 0.8972612866432508, 'lambda_12': 0.08655704137361815}. Best is trial 2 with value: 7.973338537864289.
# [I 2024-09-03 08:43:10,644] Trial 9 finished with value: 8.098598717687658 and parameters: {'num_leaves': 197, 'min_data_in_leaf': 19, 'max_bin': 348, 'bagging_fraction': 0.8058781688381481, 'eature_fraction': 0.43484208877292285, 'min_gain_to_split': 0.017393745944806985, 'lambda_11': 0.0391093317225106, 'lambda_12': 0.0172764870082179}. Best is trial 2 with value: 7.973338537864289.
# Early stopping, best iteration is:
# [56]	train's l2: 17.2641	valid's l2: 100.466
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [44]	train's l2: 21.1567	valid's l2: 105.835
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 22.2855	valid's l2: 103.353
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:10,741] Trial 10 finished with value: 7.994129971176455 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 30, 'max_bin': 391, 'bagging_fraction': 0.9394460532541745, 'eature_fraction': 0.35831680797439047, 'min_gain_to_split': 0.9422032054581796, 'lambda_11': 0.19682534332959933, 'lambda_12': 0.08310314014919823}. Best is trial 2 with value: 7.973338537864289.
# [I 2024-09-03 08:43:10,820] Trial 11 finished with value: 7.984887851659479 and parameters: {'num_leaves': 51, 'min_data_in_leaf': 30, 'max_bin': 390, 'bagging_fraction': 0.9470788137965658, 'eature_fraction': 0.3702931711227331, 'min_gain_to_split': 0.9049911227773816, 'lambda_11': 0.20707946456899806, 'lambda_12': 0.07605040755240003}. Best is trial 2 with value: 7.973338537864289.
# [I 2024-09-03 08:43:10,900] Trial 12 finished with value: 8.06900928494226 and parameters: {'num_leaves': 51, 'min_data_in_leaf': 30, 'max_bin': 391, 'bagging_fraction': 0.9168267459354958, 'eature_fraction': 0.44873443794008033, 'min_gain_to_split': 0.46434929485727805, 'lambda_11': 0.2510014839801377, 'lambda_12': 0.19097846546175865}. Best is trial 2 with value: 7.973338537864289.
# Early stopping, best iteration is:
# [120]	train's l2: 26.7092	valid's l2: 100.459
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [108]	train's l2: 27.8355	valid's l2: 99.5357
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [106]	train's l2: 25.8826	valid's l2: 101.475
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:11,024] Trial 13 finished with value: 7.894033893811312 and parameters: {'num_leaves': 81, 'min_data_in_leaf': 25, 'max_bin': 280, 'bagging_fraction': 0.9105698458084414, 'eature_fraction': 0.58559941302925, 'min_gain_to_split': 0.4109963935746489, 'lambda_11': 0.10206016615799028, 'lambda_12': 0.04439926537109432}. Best is trial 13 with value: 7.894033893811312.
# [I 2024-09-03 08:43:11,123] Trial 14 finished with value: 8.163157378729455 and parameters: {'num_leaves': 82, 'min_data_in_leaf': 25, 'max_bin': 273, 'bagging_fraction': 0.9102949061627017, 'eature_fraction': 0.6458293060912801, 'min_gain_to_split': 0.38033423333360994, 'lambda_11': 0.0873393688377658, 'lambda_12': 0.046718703736371964}. Best is trial 13 with value: 7.894033893811312.
# Early stopping, best iteration is:
# [63]	train's l2: 26.7191	valid's l2: 96.4008
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	train's l2: 24.7684	valid's l2: 105.155
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:11,300] Trial 15 finished with value: 8.348219934219635 and parameters: {'num_leaves': 163, 'min_data_in_leaf': 2, 'max_bin': 259, 'bagging_fraction': 0.9140846565334434, 'eature_fraction': 0.5924736995148715, 'min_gain_to_split': 0.08737455514948993, 'lambda_11': 0.06156381270609451, 'lambda_12': 0.03993891460285136}. Best is trial 13 with value: 7.894033893811312.
# [I 2024-09-03 08:43:11,372] Trial 16 finished with value: 7.894033893811312 and parameters: {'num_leaves': 75, 'min_data_in_leaf': 25, 'max_bin': 279, 'bagging_fraction': 0.9275106180257899, 'eature_fraction': 0.5920086213344785, 'min_gain_to_split': 0.3876262713636515, 'lambda_11': 0.4156739404762543, 'lambda_12': 0.8938989356697504}. Best is trial 13 with value: 7.894033893811312.
# [I 2024-09-03 08:43:11,470] Trial 17 finished with value: 7.898744503305259 and parameters: {'num_leaves': 94, 'min_data_in_leaf': 24, 'max_bin': 258, 'bagging_fraction': 0.8553713438669097, 'eature_fraction': 0.5763894570844404, 'min_gain_to_split': 0.04734951858490795, 'lambda_11': 0.48778760207673116, 'lambda_12': 0.7325894753516439}. Best is trial 13 with value: 7.894033893811312.
# Early stopping, best iteration is:
# [44]	train's l2: 7.98524	valid's l2: 108.895
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	train's l2: 26.7191	valid's l2: 96.4008
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	train's l2: 19.0764	valid's l2: 99.0521
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:11,556] Trial 18 finished with value: 7.841091832700407 and parameters: {'num_leaves': 114, 'min_data_in_leaf': 27, 'max_bin': 288, 'bagging_fraction': 0.8968067360777477, 'eature_fraction': 0.6062808422418011, 'min_gain_to_split': 0.14046882751234202, 'lambda_11': 0.35351762246546986, 'lambda_12': 0.15426121044656652}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:11,659] Trial 19 finished with value: 7.987526574662468 and parameters: {'num_leaves': 120, 'min_data_in_leaf': 22, 'max_bin': 236, 'bagging_fraction': 0.8904644677870199, 'eature_fraction': 0.5631091973375341, 'min_gain_to_split': 0.034712797807671655, 'lambda_11': 0.12639085106811243, 'lambda_12': 0.14385958706303073}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:11,737] Trial 20 finished with value: 8.050825822240382 and parameters: {'num_leaves': 143, 'min_data_in_leaf': 27, 'max_bin': 297, 'bagging_fraction': 0.9009220292077558, 'eature_fraction': 0.6181481261962078, 'min_gain_to_split': 0.14245774453320784, 'lambda_11': 0.3465577292729926, 'lambda_12': 0.03216315787376346}. Best is trial 18 with value: 7.841091832700407.
# Early stopping, best iteration is:
# [81]	train's l2: 24.8247	valid's l2: 94.7937
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	train's l2: 20.1633	valid's l2: 100.999
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	train's l2: 26.3098	valid's l2: 101.757
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:11,805] Trial 21 finished with value: 8.15433293464121 and parameters: {'num_leaves': 74, 'min_data_in_leaf': 27, 'max_bin': 280, 'bagging_fraction': 0.9240808648970676, 'eature_fraction': 0.6120402313259532, 'min_gain_to_split': 0.2800468145356732, 'lambda_11': 0.4912371210736349, 'lambda_12': 0.010157909744457192}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:11,945] Trial 22 finished with value: 7.847063897011603 and parameters: {'num_leaves': 102, 'min_data_in_leaf': 22, 'max_bin': 322, 'bagging_fraction': 0.9021534129235075, 'eature_fraction': 0.5763122225579689, 'min_gain_to_split': 0.11738914133701442, 'lambda_11': 0.12490704915938831, 'lambda_12': 0.41275657424252693}. Best is trial 18 with value: 7.841091832700407.
# Early stopping, best iteration is:
# [61]	train's l2: 27.5178	valid's l2: 103.306
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [172]	train's l2: 14.5111	valid's l2: 98.1033
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:12,031] Trial 23 finished with value: 7.943165380533674 and parameters: {'num_leaves': 108, 'min_data_in_leaf': 22, 'max_bin': 317, 'bagging_fraction': 0.8987151952016585, 'eature_fraction': 0.5526751698940285, 'min_gain_to_split': 0.11120568865183678, 'lambda_11': 0.13294999146946657, 'lambda_12': 0.13143017329064918}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:12,114] Trial 24 finished with value: 8.188833831423466 and parameters: {'num_leaves': 90, 'min_data_in_leaf': 16, 'max_bin': 332, 'bagging_fraction': 0.8673525866355242, 'eature_fraction': 0.5734416930473527, 'min_gain_to_split': 0.06011460290361639, 'lambda_11': 0.051903629888026416, 'lambda_12': 0.427389564536795}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:12,205] Trial 25 finished with value: 7.988872791597918 and parameters: {'num_leaves': 108, 'min_data_in_leaf': 23, 'max_bin': 252, 'bagging_fraction': 0.9078892266024947, 'eature_fraction': 0.4869325829750675, 'min_gain_to_split': 0.11203165966330063, 'lambda_11': 0.12786874885494082, 'lambda_12': 0.061567307847144925}. Best is trial 18 with value: 7.841091832700407.
# Early stopping, best iteration is:
# [75]	train's l2: 23.016	valid's l2: 99.9542
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [54]	train's l2: 22.0098	valid's l2: 106.121
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [85]	train's l2: 23.1292	valid's l2: 100.877
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:12,280] Trial 26 finished with value: 8.026343114015464 and parameters: {'num_leaves': 132, 'min_data_in_leaf': 27, 'max_bin': 304, 'bagging_fraction': 0.8854309611154391, 'eature_fraction': 0.6175204124291631, 'min_gain_to_split': 0.034232556840281654, 'lambda_11': 0.29287796111095726, 'lambda_12': 0.23582861706083266}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:12,385] Trial 27 finished with value: 7.875679772707538 and parameters: {'num_leaves': 117, 'min_data_in_leaf': 20, 'max_bin': 288, 'bagging_fraction': 0.8508702740333091, 'eature_fraction': 0.537028505503237, 'min_gain_to_split': 0.2708399503267112, 'lambda_11': 0.1641292902302395, 'lambda_12': 0.12443865861439836}. Best is trial 18 with value: 7.841091832700407.
# Early stopping, best iteration is:
# [68]	train's l2: 26.5079	valid's l2: 101.247
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [115]	train's l2: 16.8612	valid's l2: 97.9219
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:12,509] Trial 28 finished with value: 8.139318999114893 and parameters: {'num_leaves': 144, 'min_data_in_leaf': 17, 'max_bin': 305, 'bagging_fraction': 0.8472515909054394, 'eature_fraction': 0.5211419422508524, 'min_gain_to_split': 0.29069963133515986, 'lambda_11': 0.6561870912675903, 'lambda_12': 0.12813831677298643}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:12,612] Trial 29 finished with value: 8.104863748942405 and parameters: {'num_leaves': 130, 'min_data_in_leaf': 20, 'max_bin': 329, 'bagging_fraction': 0.8274394181930151, 'eature_fraction': 0.46041663239753267, 'min_gain_to_split': 0.1972416645180012, 'lambda_11': 0.15709416496571488, 'lambda_12': 0.5450444565647045}. Best is trial 18 with value: 7.841091832700407.
# Early stopping, best iteration is:
# [117]	train's l2: 15.8796	valid's l2: 105.467
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [86]	train's l2: 22.4227	valid's l2: 103.237
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:12,718] Trial 30 finished with value: 8.08366972622117 and parameters: {'num_leaves': 164, 'min_data_in_leaf': 21, 'max_bin': 322, 'bagging_fraction': 0.8603230763372732, 'eature_fraction': 0.4846791862100688, 'min_gain_to_split': 0.1443160471475043, 'lambda_11': 0.30756066745817756, 'lambda_12': 0.2911584721986198}. Best is trial 18 with value: 7.841091832700407.
# [I 2024-09-03 08:43:12,793] Trial 31 finished with value: 7.8238259081490815 and parameters: {'num_leaves': 114, 'min_data_in_leaf': 28, 'max_bin': 286, 'bagging_fraction': 0.8769551978530508, 'eature_fraction': 0.5369966458484355, 'min_gain_to_split': 0.571152692943046, 'lambda_11': 0.10620181082906743, 'lambda_12': 0.10959105751888577}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:12,874] Trial 32 finished with value: 7.884415199543237 and parameters: {'num_leaves': 115, 'min_data_in_leaf': 28, 'max_bin': 267, 'bagging_fraction': 0.8741194602507022, 'eature_fraction': 0.5479955319607204, 'min_gain_to_split': 0.6170684557298901, 'lambda_11': 0.16914736028868682, 'lambda_12': 0.17054538794199453}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [70]	train's l2: 24.4102	valid's l2: 104.064
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [65]	train's l2: 27.6527	valid's l2: 97.3342
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	train's l2: 27.2572	valid's l2: 98.141
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:13,024] Trial 33 finished with value: 8.024873351315827 and parameters: {'num_leaves': 126, 'min_data_in_leaf': 23, 'max_bin': 290, 'bagging_fraction': 0.8843112178117079, 'eature_fraction': 0.5261174239329909, 'min_gain_to_split': 0.5732538830699875, 'lambda_11': 0.06289089014732534, 'lambda_12': 0.1112298129945375}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:13,115] Trial 34 finished with value: 8.07423477279855 and parameters: {'num_leaves': 102, 'min_data_in_leaf': 28, 'max_bin': 246, 'bagging_fraction': 0.8761672319272413, 'eature_fraction': 0.5039794182925476, 'min_gain_to_split': 0.27635239871471673, 'lambda_11': 0.11269893338329404, 'lambda_12': 0.5003682321540197}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [81]	train's l2: 23.7642	valid's l2: 102.376
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [82]	train's l2: 26.0958	valid's l2: 102.479
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [101]	train's l2: 19.1752	valid's l2: 103.333
# [I 2024-09-03 08:43:13,221] Trial 35 finished with value: 8.004584551150613 and parameters: {'num_leaves': 117, 'min_data_in_leaf': 21, 'max_bin': 310, 'bagging_fraction': 0.8458061462123181, 'eature_fraction': 0.5362010662332304, 'min_gain_to_split': 0.08519313072302702, 'lambda_11': 0.0768398560086285, 'lambda_12': 0.22740937858806567}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:13,323] Trial 36 finished with value: 8.082150146166208 and parameters: {'num_leaves': 138, 'min_data_in_leaf': 18, 'max_bin': 294, 'bagging_fraction': 0.8979867057986436, 'eature_fraction': 0.5649018204316206, 'min_gain_to_split': 0.23406818644875585, 'lambda_11': 0.23264609543973103, 'lambda_12': 0.33780943929121915}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:13,419] Trial 37 finished with value: 8.193959149359992 and parameters: {'num_leaves': 63, 'min_data_in_leaf': 15, 'max_bin': 211, 'bagging_fraction': 0.8716583438397638, 'eature_fraction': 0.6222038842169176, 'min_gain_to_split': 0.15752801219801335, 'lambda_11': 0.16853428332027542, 'lambda_12': 0.06549348944535523}. Best is trial 31 with value: 7.8238259081490815.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [55]	train's l2: 23.3947	valid's l2: 103.405
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [52]	train's l2: 21.9265	valid's l2: 105.72
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:13,518] Trial 38 finished with value: 8.037156264679542 and parameters: {'num_leaves': 90, 'min_data_in_leaf': 28, 'max_bin': 360, 'bagging_fraction': 0.8539706151320786, 'eature_fraction': 0.511599292244269, 'min_gain_to_split': 0.5370448432506285, 'lambda_11': 0.01739180481071622, 'lambda_12': 0.10225841971061676}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:13,667] Trial 39 finished with value: 8.15288348118835 and parameters: {'num_leaves': 154, 'min_data_in_leaf': 9, 'max_bin': 284, 'bagging_fraction': 0.830328505940103, 'eature_fraction': 0.5431595687372418, 'min_gain_to_split': 0.12514796201210704, 'lambda_11': 0.09339947701604051, 'lambda_12': 0.17643750617964096}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [82]	train's l2: 26.1922	valid's l2: 101.937
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [41]	train's l2: 17.6556	valid's l2: 105.717
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:13,753] Trial 40 finished with value: 8.019253507689621 and parameters: {'num_leaves': 112, 'min_data_in_leaf': 24, 'max_bin': 338, 'bagging_fraction': 0.8884686244582848, 'eature_fraction': 0.6289789508428291, 'min_gain_to_split': 0.1845953312827711, 'lambda_11': 0.412115338864823, 'lambda_12': 0.2531233362355415}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:13,832] Trial 41 finished with value: 7.958181665133357 and parameters: {'num_leaves': 120, 'min_data_in_leaf': 29, 'max_bin': 265, 'bagging_fraction': 0.8780111464515905, 'eature_fraction': 0.5472121842816747, 'min_gain_to_split': 0.6661181622323726, 'lambda_11': 0.14819169219639583, 'lambda_12': 0.14790366135824928}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:13,947] Trial 42 finished with value: 7.915842285024575 and parameters: {'num_leaves': 101, 'min_data_in_leaf': 26, 'max_bin': 266, 'bagging_fraction': 0.8643262322672823, 'eature_fraction': 0.5609388993984517, 'min_gain_to_split': 0.8031311417348529, 'lambda_11': 0.18732922915232633, 'lambda_12': 0.18044322367042653}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [70]	train's l2: 24.254	valid's l2: 101.217
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	train's l2: 27.0411	valid's l2: 100.434
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [112]	train's l2: 20.9903	valid's l2: 97.1289
# [I 2024-09-03 08:43:14,037] Trial 43 finished with value: 7.873999889128816 and parameters: {'num_leaves': 111, 'min_data_in_leaf': 28, 'max_bin': 272, 'bagging_fraction': 0.8721438803404928, 'eature_fraction': 0.6015783864582902, 'min_gain_to_split': 0.3403990392385436, 'lambda_11': 0.049760166411827275, 'lambda_12': 0.09909760946657016}. Best is trial 31 with value: 7.8238259081490815.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 25.3686	valid's l2: 98.0009
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:14,214] Trial 44 finished with value: 7.999680871879204 and parameters: {'num_leaves': 126, 'min_data_in_leaf': 19, 'max_bin': 241, 'bagging_fraction': 0.8940067397390498, 'eature_fraction': 0.6000577496416638, 'min_gain_to_split': 0.23888896241794755, 'lambda_11': 0.04495057158845158, 'lambda_12': 0.05988666142336917}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:14,308] Trial 45 finished with value: 7.99362480848581 and parameters: {'num_leaves': 97, 'min_data_in_leaf': 26, 'max_bin': 289, 'bagging_fraction': 0.8826511208170924, 'eature_fraction': 0.6319257484200289, 'min_gain_to_split': 0.32289746572470035, 'lambda_11': 0.023832322307667252, 'lambda_12': 0.08214040868485498}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:14,373] Trial 46 finished with value: 7.975916860843014 and parameters: {'num_leaves': 109, 'min_data_in_leaf': 29, 'max_bin': 323, 'bagging_fraction': 0.9024660323618267, 'eature_fraction': 0.5791817535293751, 'min_gain_to_split': 0.33822072459539215, 'lambda_11': 0.010723370311862029, 'lambda_12': 0.1083718707497855}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [131]	train's l2: 15.1743	valid's l2: 102.105
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 25.6135	valid's l2: 100.235
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [48]	train's l2: 31.6136	valid's l2: 100.185
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:14,490] Trial 47 finished with value: 7.914729671341252 and parameters: {'num_leaves': 136, 'min_data_in_leaf': 24, 'max_bin': 302, 'bagging_fraction': 0.8405615812685675, 'eature_fraction': 0.5982239278734852, 'min_gain_to_split': 0.011713072238696715, 'lambda_11': 0.03599759553560018, 'lambda_12': 0.03248709084468485}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:14,558] Trial 48 finished with value: 7.973585540880001 and parameters: {'num_leaves': 88, 'min_data_in_leaf': 26, 'max_bin': 274, 'bagging_fraction': 0.9195411516836421, 'eature_fraction': 0.605282648200134, 'min_gain_to_split': 0.47429295746043226, 'lambda_11': 0.06782658369450258, 'lambda_12': 0.08760641834037085}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:14,649] Trial 49 finished with value: 7.879856459394048 and parameters: {'num_leaves': 123, 'min_data_in_leaf': 30, 'max_bin': 378, 'bagging_fraction': 0.8557354720928018, 'eature_fraction': 0.5842603810069745, 'min_gain_to_split': 0.0822972400605102, 'lambda_11': 0.029969157513711427, 'lambda_12': 0.38982965104562106}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [136]	train's l2: 17.6321	valid's l2: 98.1481
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	train's l2: 25.3664	valid's l2: 99.2779
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [104]	train's l2: 23.4373	valid's l2: 97.9187
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:14,769] Trial 50 finished with value: 8.19082289379627 and parameters: {'num_leaves': 103, 'min_data_in_leaf': 2, 'max_bin': 287, 'bagging_fraction': 0.9348040839106885, 'eature_fraction': 0.5309048377194829, 'min_gain_to_split': 0.21000361671549744, 'lambda_11': 0.09541437079063755, 'lambda_12': 0.06970991528198746}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:14,860] Trial 51 finished with value: 7.864329491377193 and parameters: {'num_leaves': 123, 'min_data_in_leaf': 30, 'max_bin': 380, 'bagging_fraction': 0.8562140403631707, 'eature_fraction': 0.5841195953645747, 'min_gain_to_split': 0.07071453403553643, 'lambda_11': 0.031267738206558024, 'lambda_12': 0.42395692211127045}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [49]	train's l2: 12.108	valid's l2: 104.522
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	train's l2: 27.7508	valid's l2: 98.1261
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:14,974] Trial 52 finished with value: 7.862921446837158 and parameters: {'num_leaves': 114, 'min_data_in_leaf': 29, 'max_bin': 346, 'bagging_fraction': 0.862327075546818, 'eature_fraction': 0.5670251828474759, 'min_gain_to_split': 0.0644796272149522, 'lambda_11': 0.04854797323095111, 'lambda_12': 0.6617542726036619}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:15,070] Trial 53 finished with value: 7.866366300313959 and parameters: {'num_leaves': 190, 'min_data_in_leaf': 30, 'max_bin': 348, 'bagging_fraction': 0.8652190738873935, 'eature_fraction': 0.5721761796680498, 'min_gain_to_split': 0.061524030901591614, 'lambda_11': 0.019781511554739478, 'lambda_12': 0.6918683927544341}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:15,160] Trial 54 finished with value: 7.83077433886959 and parameters: {'num_leaves': 190, 'min_data_in_leaf': 30, 'max_bin': 352, 'bagging_fraction': 0.8643760193952981, 'eature_fraction': 0.5642731387783437, 'min_gain_to_split': 0.05589801591714915, 'lambda_11': 0.01957861804050493, 'lambda_12': 0.9573454204290066}. Best is trial 31 with value: 7.8238259081490815.
# Early stopping, best iteration is:
# [72]	train's l2: 27.0207	valid's l2: 97.7208
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [114]	train's l2: 22.4275	valid's l2: 97.6541
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [78]	train's l2: 26.4114	valid's l2: 97.1543
# [I 2024-09-03 08:43:15,248] Trial 55 finished with value: 7.867086861375986 and parameters: {'num_leaves': 151, 'min_data_in_leaf': 29, 'max_bin': 350, 'bagging_fraction': 0.861437917820008, 'eature_fraction': 0.5646884081663017, 'min_gain_to_split': 0.036251331898570514, 'lambda_11': 0.014282247617649773, 'lambda_12': 0.954463804014921}. Best is trial 31 with value: 7.8238259081490815.
# [I 2024-09-03 08:43:15,353] Trial 56 finished with value: 7.86123594545753 and parameters: {'num_leaves': 170, 'min_data_in_leaf': 29, 'max_bin': 374, 'bagging_fraction': 0.8700937539588428, 'eature_fraction': 0.5573034840083733, 'min_gain_to_split': 0.04859777626052174, 'lambda_11': 0.026507795874758218, 'lambda_12': 0.8045539186908368}. Best is trial 31 with value: 7.8238259081490815.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	train's l2: 28.4972	valid's l2: 98.1501
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	train's l2: 27.142	valid's l2: 97.6223
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:15,452] Trial 57 finished with value: 7.786888845630673 and parameters: {'num_leaves': 181, 'min_data_in_leaf': 27, 'max_bin': 369, 'bagging_fraction': 0.8793802427695177, 'eature_fraction': 0.5564007464390122, 'min_gain_to_split': 0.0252182085906093, 'lambda_11': 0.021739007610073295, 'lambda_12': 0.7556468914850103}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:15,576] Trial 58 finished with value: 7.9944855767476986 and parameters: {'num_leaves': 190, 'min_data_in_leaf': 27, 'max_bin': 370, 'bagging_fraction': 0.9060316819755053, 'eature_fraction': 0.5141561492170792, 'min_gain_to_split': 0.021895658712494305, 'lambda_11': 0.021426221900088905, 'lambda_12': 0.8127965044271606}. Best is trial 57 with value: 7.786888845630673.
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3939
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [124]	train's l2: 21.5662	valid's l2: 100.965
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:15,687] Trial 59 finished with value: 7.875980656314739 and parameters: {'num_leaves': 178, 'min_data_in_leaf': 25, 'max_bin': 398, 'bagging_fraction': 0.8924671048122612, 'eature_fraction': 0.5553863913887633, 'min_gain_to_split': 0.04350018171327611, 'lambda_11': 0.015092923966203693, 'lambda_12': 0.5718858321943502}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:15,795] Trial 60 finished with value: 8.01120169562223 and parameters: {'num_leaves': 168, 'min_data_in_leaf': 26, 'max_bin': 368, 'bagging_fraction': 0.8788922106368585, 'eature_fraction': 0.4962579371034408, 'min_gain_to_split': 0.043367993932130144, 'lambda_11': 0.03981758483449268, 'lambda_12': 0.9991641642889114}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:15,882] Trial 61 finished with value: 7.87286733295413 and parameters: {'num_leaves': 182, 'min_data_in_leaf': 29, 'max_bin': 355, 'bagging_fraction': 0.8703439575679783, 'eature_fraction': 0.5709948151012495, 'min_gain_to_split': 0.024937766717214652, 'lambda_11': 0.024108929702367395, 'lambda_12': 0.6896162088798792}. Best is trial 57 with value: 7.786888845630673.
# Early stopping, best iteration is:
# [112]	train's l2: 20.3454	valid's l2: 97.8901
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	train's l2: 21.6863	valid's l2: 101.306
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	train's l2: 28.7629	valid's l2: 98.0321
# [I 2024-09-03 08:43:15,981] Trial 62 finished with value: 7.901458624848357 and parameters: {'num_leaves': 198, 'min_data_in_leaf': 27, 'max_bin': 338, 'bagging_fraction': 0.88129230530185, 'eature_fraction': 0.5903581813924909, 'min_gain_to_split': 0.055359703358347945, 'lambda_11': 0.011472888123861989, 'lambda_12': 0.49063025217752027}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:16,074] Trial 63 finished with value: 7.858825484180459 and parameters: {'num_leaves': 178, 'min_data_in_leaf': 28, 'max_bin': 382, 'bagging_fraction': 0.8958128049312915, 'eature_fraction': 0.5578044957093565, 'min_gain_to_split': 0.02839088108401824, 'lambda_11': 0.028156443452244946, 'lambda_12': 0.8227113958463305}. Best is trial 57 with value: 7.786888845630673.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [69]	train's l2: 26.6317	valid's l2: 97.2759
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	train's l2: 26.4422	valid's l2: 98.0193
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:16,172] Trial 64 finished with value: 7.85882212225558 and parameters: {'num_leaves': 174, 'min_data_in_leaf': 28, 'max_bin': 380, 'bagging_fraction': 0.8943445500890018, 'eature_fraction': 0.5518388001878153, 'min_gain_to_split': 0.02467073291403903, 'lambda_11': 0.017895354893841527, 'lambda_12': 0.8463040508118916}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:16,309] Trial 65 finished with value: 8.032414412729146 and parameters: {'num_leaves': 178, 'min_data_in_leaf': 23, 'max_bin': 387, 'bagging_fraction': 0.8953104057931939, 'eature_fraction': 0.39851367474500143, 'min_gain_to_split': 0.026415612252969102, 'lambda_11': 0.017277690930423976, 'lambda_12': 0.8326987774599918}. Best is trial 57 with value: 7.786888845630673.
# Early stopping, best iteration is:
# [72]	train's l2: 26.4423	valid's l2: 98.0193
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	train's l2: 23.6257	valid's l2: 101.799
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:16,390] Trial 66 finished with value: 7.846688825367684 and parameters: {'num_leaves': 191, 'min_data_in_leaf': 25, 'max_bin': 361, 'bagging_fraction': 0.8881388984274992, 'eature_fraction': 0.5422089498493488, 'min_gain_to_split': 0.018686184764452062, 'lambda_11': 0.017905661710137, 'lambda_12': 0.33057412279004716}. Best is trial 57 with value: 7.786888845630673.
# Early stopping, best iteration is:
# [75]	train's l2: 24.8744	valid's l2: 96.4441
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [276]	train's l2: 11.2705	valid's l2: 96.8402
# [I 2024-09-03 08:43:16,592] Trial 67 finished with value: 7.841588301411887 and parameters: {'num_leaves': 188, 'min_data_in_leaf': 24, 'max_bin': 364, 'bagging_fraction': 0.8873274869343712, 'eature_fraction': 0.5406216091284087, 'min_gain_to_split': 0.013610714669689957, 'lambda_11': 0.017210530456428598, 'lambda_12': 0.3143462322016684}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:16,683] Trial 68 finished with value: 7.944173023734337 and parameters: {'num_leaves': 188, 'min_data_in_leaf': 24, 'max_bin': 361, 'bagging_fraction': 0.9045912560706731, 'eature_fraction': 0.536991292329029, 'min_gain_to_split': 0.012652886994851346, 'lambda_11': 0.013633594559111199, 'lambda_12': 0.3053796549057848}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:16,792] Trial 69 finished with value: 7.965079526976643 and parameters: {'num_leaves': 185, 'min_data_in_leaf': 25, 'max_bin': 332, 'bagging_fraction': 0.888062332492153, 'eature_fraction': 0.5214697644869011, 'min_gain_to_split': 0.018542245796791024, 'lambda_11': 0.012578852627870011, 'lambda_12': 0.20594807335279675}. Best is trial 57 with value: 7.786888845630673.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [78]	train's l2: 23.6105	valid's l2: 99.142
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	train's l2: 23.9739	valid's l2: 100.054
# [I 2024-09-03 08:43:16,937] Trial 70 finished with value: 7.837003043200325 and parameters: {'num_leaves': 200, 'min_data_in_leaf': 21, 'max_bin': 353, 'bagging_fraction': 0.8882792620190904, 'eature_fraction': 0.5404712368577195, 'min_gain_to_split': 0.013985431326966776, 'lambda_11': 0.01583991583250185, 'lambda_12': 0.2735754407390198}. Best is trial 57 with value: 7.786888845630673.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [141]	train's l2: 15.5997	valid's l2: 98.2369
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:17,027] Trial 71 finished with value: 7.919343666934897 and parameters: {'num_leaves': 200, 'min_data_in_leaf': 21, 'max_bin': 364, 'bagging_fraction': 0.8854469705542246, 'eature_fraction': 0.5411899654445352, 'min_gain_to_split': 0.01047287823714441, 'lambda_11': 0.015930051224258848, 'lambda_12': 0.26657094193789904}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:17,146] Trial 72 finished with value: 7.950288669641371 and parameters: {'num_leaves': 196, 'min_data_in_leaf': 22, 'max_bin': 353, 'bagging_fraction': 0.9141606908971158, 'eature_fraction': 0.5273972425244581, 'min_gain_to_split': 0.01555047174431553, 'lambda_11': 0.6571805623096457, 'lambda_12': 0.3409993432393751}. Best is trial 57 with value: 7.786888845630673.
# Early stopping, best iteration is:
# [69]	train's l2: 23.1828	valid's l2: 100.093
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [86]	train's l2: 22.4225	valid's l2: 99.8507
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:17,261] Trial 73 finished with value: 8.015452925320217 and parameters: {'num_leaves': 192, 'min_data_in_leaf': 23, 'max_bin': 341, 'bagging_fraction': 0.888517189603464, 'eature_fraction': 0.5133816756587742, 'min_gain_to_split': 0.014042908960846682, 'lambda_11': 0.01000949293423747, 'lambda_12': 0.49119936689895166}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:17,440] Trial 74 finished with value: 8.3115080113816 and parameters: {'num_leaves': 194, 'min_data_in_leaf': 5, 'max_bin': 312, 'bagging_fraction': 0.9012844456563668, 'eature_fraction': 0.49797927140237525, 'min_gain_to_split': 0.01931563468588048, 'lambda_11': 0.021876546933395774, 'lambda_12': 0.3960153212012983}. Best is trial 57 with value: 7.786888845630673.
# Early stopping, best iteration is:
# [84]	train's l2: 23.3353	valid's l2: 102.419
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [50]	train's l2: 10.6465	valid's l2: 106.649
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:17,503] Trial 75 finished with value: 7.970829180391994 and parameters: {'num_leaves': 183, 'min_data_in_leaf': 25, 'max_bin': 357, 'bagging_fraction': 0.875607134081527, 'eature_fraction': 0.5436369165913201, 'min_gain_to_split': 0.014928664360498693, 'lambda_11': 0.013278191852519668, 'lambda_12': 0.15165464294680064}. Best is trial 57 with value: 7.786888845630673.
# [I 2024-09-03 08:43:17,579] Trial 76 finished with value: 7.786672694536484 and parameters: {'num_leaves': 200, 'min_data_in_leaf': 27, 'max_bin': 372, 'bagging_fraction': 0.8802623614266789, 'eature_fraction': 0.5775175565106739, 'min_gain_to_split': 0.020702400679126452, 'lambda_11': 0.019525800225557076, 'lambda_12': 0.2905569907616756}. Best is trial 76 with value: 7.786672694536484.
# [I 2024-09-03 08:43:17,662] Trial 77 finished with value: 8.025643491811428 and parameters: {'num_leaves': 185, 'min_data_in_leaf': 27, 'max_bin': 374, 'bagging_fraction': 0.8803750337706675, 'eature_fraction': 0.6102600458145347, 'min_gain_to_split': 0.030800309858456987, 'lambda_11': 0.019263357980449095, 'lambda_12': 0.20986285613370376}. Best is trial 76 with value: 7.786672694536484.
# Early stopping, best iteration is:
# [51]	train's l2: 29.1576	valid's l2: 99.2123
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3872
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 26.5078	valid's l2: 101.23
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:17,754] Trial 78 finished with value: 7.977183387995999 and parameters: {'num_leaves': 196, 'min_data_in_leaf': 26, 'max_bin': 396, 'bagging_fraction': 0.8844355349314176, 'eature_fraction': 0.5308589990642059, 'min_gain_to_split': 0.019740025685724714, 'lambda_11': 0.01218472724900136, 'lambda_12': 0.2904758241125716}. Best is trial 76 with value: 7.786672694536484.
# [I 2024-09-03 08:43:17,870] Trial 79 finished with value: 7.994641111788338 and parameters: {'num_leaves': 187, 'min_data_in_leaf': 27, 'max_bin': 371, 'bagging_fraction': 0.8911026510165831, 'eature_fraction': 0.4683986017072311, 'min_gain_to_split': 0.022193731358619496, 'lambda_11': 0.01613262038820474, 'lambda_12': 0.1595791933598566}. Best is trial 76 with value: 7.786672694536484.
# Early stopping, best iteration is:
# [91]	train's l2: 23.9496	valid's l2: 100.152
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [124]	train's l2: 21.5662	valid's l2: 100.975
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:17,999] Trial 80 finished with value: 7.940774753180053 and parameters: {'num_leaves': 200, 'min_data_in_leaf': 24, 'max_bin': 365, 'bagging_fraction': 0.8676431275154739, 'eature_fraction': 0.57853413871144, 'min_gain_to_split': 0.010097210615247137, 'lambda_11': 0.9337502753481365, 'lambda_12': 0.3137282108751834}. Best is trial 76 with value: 7.786672694536484.
# [I 2024-09-03 08:43:18,114] Trial 81 finished with value: 7.926328978337181 and parameters: {'num_leaves': 194, 'min_data_in_leaf': 22, 'max_bin': 360, 'bagging_fraction': 0.8985278518215444, 'eature_fraction': 0.5909975171115653, 'min_gain_to_split': 0.0950084674773521, 'lambda_11': 0.11634735251621202, 'lambda_12': 0.25694956570869626}. Best is trial 76 with value: 7.786672694536484.
# Early stopping, best iteration is:
# [109]	train's l2: 19.9021	valid's l2: 99.0508
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	train's l2: 19.3875	valid's l2: 99.6567
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [71]	train's l2: 23.9546	valid's l2: 102.903
# [I 2024-09-03 08:43:18,198] Trial 82 finished with value: 8.061794739464366 and parameters: {'num_leaves': 160, 'min_data_in_leaf': 23, 'max_bin': 386, 'bagging_fraction': 0.876038395394081, 'eature_fraction': 0.5480202800157614, 'min_gain_to_split': 0.01683639279354715, 'lambda_11': 0.021449964324453976, 'lambda_12': 0.4673384172614609}. Best is trial 76 with value: 7.786672694536484.
# [I 2024-09-03 08:43:18,313] Trial 83 finished with value: 7.961400736752294 and parameters: {'num_leaves': 181, 'min_data_in_leaf': 26, 'max_bin': 297, 'bagging_fraction': 0.9099847989847822, 'eature_fraction': 0.5771769191331272, 'min_gain_to_split': 0.013278973126406126, 'lambda_11': 0.23711399506120182, 'lambda_12': 0.5961358234937628}. Best is trial 76 with value: 7.786672694536484.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [111]	train's l2: 20.6488	valid's l2: 99.065
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:18,417] Trial 84 finished with value: 7.846688825367684 and parameters: {'num_leaves': 98, 'min_data_in_leaf': 25, 'max_bin': 343, 'bagging_fraction': 0.8873853698851792, 'eature_fraction': 0.5676173213545148, 'min_gain_to_split': 0.021944692034442756, 'lambda_11': 0.08429834194379905, 'lambda_12': 0.37043489198816376}. Best is trial 76 with value: 7.786672694536484.
# [I 2024-09-03 08:43:18,517] Trial 85 finished with value: 7.846688825367684 and parameters: {'num_leaves': 193, 'min_data_in_leaf': 25, 'max_bin': 346, 'bagging_fraction': 0.885467175993513, 'eature_fraction': 0.5596881191014266, 'min_gain_to_split': 0.021844373990221034, 'lambda_11': 0.0248732635585192, 'lambda_12': 0.37603948220815214}. Best is trial 76 with value: 7.786672694536484.
# Early stopping, best iteration is:
# [75]	train's l2: 24.8744	valid's l2: 96.4441
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	train's l2: 24.8744	valid's l2: 96.4441
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:18,632] Trial 86 finished with value: 8.045274724174138 and parameters: {'num_leaves': 97, 'min_data_in_leaf': 13, 'max_bin': 353, 'bagging_fraction': 0.8798125798453688, 'eature_fraction': 0.5225680847899061, 'min_gain_to_split': 0.016600487968156066, 'lambda_11': 0.03319527870210519, 'lambda_12': 0.2017851924202565}. Best is trial 76 with value: 7.786672694536484.
# [I 2024-09-03 08:43:18,703] Trial 87 finished with value: 7.881618286555651 and parameters: {'num_leaves': 174, 'min_data_in_leaf': 28, 'max_bin': 341, 'bagging_fraction': 0.8739851999481651, 'eature_fraction': 0.5397217452999304, 'min_gain_to_split': 0.011500611596504102, 'lambda_11': 0.01934961147497304, 'lambda_12': 0.23689846305358653}. Best is trial 76 with value: 7.786672694536484.
# [I 2024-09-03 08:43:18,782] Trial 88 finished with value: 8.013536160944883 and parameters: {'num_leaves': 190, 'min_data_in_leaf': 26, 'max_bin': 327, 'bagging_fraction': 0.8896095193580085, 'eature_fraction': 0.5693325321139412, 'min_gain_to_split': 0.03036369618680919, 'lambda_11': 0.014429094320291016, 'lambda_12': 0.33949745461684844}. Best is trial 76 with value: 7.786672694536484.
# Early stopping, best iteration is:
# [70]	train's l2: 17.6554	valid's l2: 103.022
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	train's l2: 26.3929	valid's l2: 98.3081
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	train's l2: 27.0249	valid's l2: 100.295
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:43:18,870] Trial 89 finished with value: 7.845370582547066 and parameters: {'num_leaves': 85, 'min_data_in_leaf': 25, 'max_bin': 366, 'bagging_fraction': 0.8694863678809363, 'eature_fraction': 0.550292929438892, 'min_gain_to_split': 0.021011887850753384, 'lambda_11': 0.08011692248317626, 'lambda_12': 0.28270369496065634}. Best is trial 76 with value: 7.786672694536484.
# ...
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	train's l2: 25.4114	valid's l2: 101.039
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [116]	train's l2: 20.3514	valid's l2: 100.096
# [I 2024-09-03 08:45:34,996] Trial 1471 finished with value: 8.05608046481176 and parameters: {'num_leaves': 148, 'min_data_in_leaf': 27, 'max_bin': 324, 'bagging_fraction': 0.8675866854110726, 'eature_fraction': 0.4676428586291484, 'min_gain_to_split': 0.049400685843008094, 'lambda_11': 0.5142152700357392, 'lambda_12': 0.027461237120799974}. Best is trial 868 with value: 7.785396231883049.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [110]	train's l2: 22.85	valid's l2: 102.012
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:35,136] Trial 1472 finished with value: 7.858825484180459 and parameters: {'num_leaves': 139, 'min_data_in_leaf': 28, 'max_bin': 211, 'bagging_fraction': 0.8547438613324426, 'eature_fraction': 0.5633940404103114, 'min_gain_to_split': 0.027156400131585646, 'lambda_11': 0.5906966822612998, 'lambda_12': 0.019010176135038057}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:35,243] Trial 1473 finished with value: 7.786671713871124 and parameters: {'num_leaves': 112, 'min_data_in_leaf': 27, 'max_bin': 205, 'bagging_fraction': 0.85959498736469, 'eature_fraction': 0.5739978939690812, 'min_gain_to_split': 0.023483329621522605, 'lambda_11': 0.7396449399214592, 'lambda_12': 0.03291780093089184}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [72]	train's l2: 26.4422	valid's l2: 98.0193
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3872
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:35,344] Trial 1474 finished with value: 7.941097162510354 and parameters: {'num_leaves': 89, 'min_data_in_leaf': 26, 'max_bin': 310, 'bagging_fraction': 0.8633339096369154, 'eature_fraction': 0.5558467240678333, 'min_gain_to_split': 0.8762207772698714, 'lambda_11': 0.2593923899784497, 'lambda_12': 0.02438482957094805}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:35,455] Trial 1475 finished with value: 7.9626479260818215 and parameters: {'num_leaves': 149, 'min_data_in_leaf': 28, 'max_bin': 224, 'bagging_fraction': 0.8533071266025263, 'eature_fraction': 0.5277234878109185, 'min_gain_to_split': 0.03471509994778846, 'lambda_11': 0.049184111507223446, 'lambda_12': 0.021694216812559435}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [76]	train's l2: 25.3837	valid's l2: 97.7035
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	train's l2: 25.2245	valid's l2: 99.777
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:35,556] Trial 1476 finished with value: 7.786654405759632 and parameters: {'num_leaves': 57, 'min_data_in_leaf': 27, 'max_bin': 300, 'bagging_fraction': 0.8614091973080753, 'eature_fraction': 0.5691061531422786, 'min_gain_to_split': 0.030401120821684977, 'lambda_11': 0.7985444996629442, 'lambda_12': 0.011875114545189414}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:35,674] Trial 1477 finished with value: 7.880311149621163 and parameters: {'num_leaves': 79, 'min_data_in_leaf': 25, 'max_bin': 209, 'bagging_fraction': 0.8568626611359283, 'eature_fraction': 0.5935442999697651, 'min_gain_to_split': 0.027180612746886434, 'lambda_11': 0.6430084587285686, 'lambda_12': 0.029962726725082794}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3872
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 23.8954	valid's l2: 97.9355
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:35,813] Trial 1478 finished with value: 8.019536710523667 and parameters: {'num_leaves': 169, 'min_data_in_leaf': 26, 'max_bin': 229, 'bagging_fraction': 0.8660717809584567, 'eature_fraction': 0.5494772827946257, 'min_gain_to_split': 0.023809126515525057, 'lambda_11': 0.8347931917349125, 'lambda_12': 0.03497018061486874}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:35,923] Trial 1479 finished with value: 7.786671713871124 and parameters: {'num_leaves': 164, 'min_data_in_leaf': 27, 'max_bin': 305, 'bagging_fraction': 0.8581838979748441, 'eature_fraction': 0.5587815976853029, 'min_gain_to_split': 0.025850925006791627, 'lambda_11': 0.9082161646980581, 'lambda_12': 0.02709618564852139}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [116]	train's l2: 20.3514	valid's l2: 100.097
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3872
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:36,041] Trial 1480 finished with value: 8.011863312337479 and parameters: {'num_leaves': 67, 'min_data_in_leaf': 28, 'max_bin': 218, 'bagging_fraction': 0.8740090612916929, 'eature_fraction': 0.5030389026716885, 'min_gain_to_split': 0.03190953348851033, 'lambda_11': 0.09380281569739486, 'lambda_12': 0.03151547807987894}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:36,152] Trial 1481 finished with value: 7.786671713871124 and parameters: {'num_leaves': 143, 'min_data_in_leaf': 27, 'max_bin': 213, 'bagging_fraction': 0.8697257086114865, 'eature_fraction': 0.5791695462852063, 'min_gain_to_split': 0.0291136521987869, 'lambda_11': 0.699373447282726, 'lambda_12': 0.024271205624189537}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [87]	train's l2: 25.4315	valid's l2: 100.416
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3872
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:36,276] Trial 1482 finished with value: 8.019698964616929 and parameters: {'num_leaves': 152, 'min_data_in_leaf': 26, 'max_bin': 205, 'bagging_fraction': 0.8619819311368296, 'eature_fraction': 0.540697198059478, 'min_gain_to_split': 0.023319346162851244, 'lambda_11': 0.4826879194780172, 'lambda_12': 0.028602128287440683}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:36,379] Trial 1483 finished with value: 7.859169358081934 and parameters: {'num_leaves': 162, 'min_data_in_leaf': 28, 'max_bin': 215, 'bagging_fraction': 0.8549688662066585, 'eature_fraction': 0.5652814280927839, 'min_gain_to_split': 0.026397803612399823, 'lambda_11': 0.9954360082910421, 'lambda_12': 0.020259775092401327}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [116]	train's l2: 20.3514	valid's l2: 100.097
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	train's l2: 26.4422	valid's l2: 98.0198
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:36,489] Trial 1484 finished with value: 7.958996405093268 and parameters: {'num_leaves': 82, 'min_data_in_leaf': 27, 'max_bin': 220, 'bagging_fraction': 0.8515915899732652, 'eature_fraction': 0.3629792829079239, 'min_gain_to_split': 0.03647228295230215, 'lambda_11': 0.5513917238022196, 'lambda_12': 0.03789957836823785}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:36,596] Trial 1485 finished with value: 7.87286733295413 and parameters: {'num_leaves': 166, 'min_data_in_leaf': 29, 'max_bin': 210, 'bagging_fraction': 0.8656857749195576, 'eature_fraction': 0.5876484042819431, 'min_gain_to_split': 0.02458853163372775, 'lambda_11': 0.7349947657625896, 'lambda_12': 0.026788929596731424}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [80]	train's l2: 29.5348	valid's l2: 98.144
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	train's l2: 28.7629	valid's l2: 98.0321
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:36,709] Trial 1486 finished with value: 7.88726716120153 and parameters: {'num_leaves': 148, 'min_data_in_leaf': 26, 'max_bin': 207, 'bagging_fraction': 0.8583760641672941, 'eature_fraction': 0.5522027277856584, 'min_gain_to_split': 0.7089469350560006, 'lambda_11': 0.8530984224521752, 'lambda_12': 0.03322133616158214}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:36,817] Trial 1487 finished with value: 7.786493663586708 and parameters: {'num_leaves': 152, 'min_data_in_leaf': 27, 'max_bin': 215, 'bagging_fraction': 0.861183916359075, 'eature_fraction': 0.5454871919587622, 'min_gain_to_split': 0.028886108847837884, 'lambda_11': 0.9987345399349326, 'lambda_12': 0.02255777827647248}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [70]	train's l2: 26.0965	valid's l2: 97.2584
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3867
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:36,915] Trial 1488 finished with value: 8.001879108429808 and parameters: {'num_leaves': 146, 'min_data_in_leaf': 28, 'max_bin': 224, 'bagging_fraction': 0.8542884597918459, 'eature_fraction': 0.378591963702757, 'min_gain_to_split': 0.022233254041708568, 'lambda_11': 0.6316824940390511, 'lambda_12': 0.02572544638933581}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:37,035] Trial 1489 finished with value: 7.880631367189602 and parameters: {'num_leaves': 162, 'min_data_in_leaf': 25, 'max_bin': 203, 'bagging_fraction': 0.8639797143821846, 'eature_fraction': 0.572892519455692, 'min_gain_to_split': 0.03118088410153304, 'lambda_11': 0.792266303549966, 'lambda_12': 0.03003039989646925}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [58]	train's l2: 33.4628	valid's l2: 99.876
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 23.8959	valid's l2: 97.9436
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:37,153] Trial 1490 finished with value: 8.009615659120737 and parameters: {'num_leaves': 154, 'min_data_in_leaf': 27, 'max_bin': 214, 'bagging_fraction': 0.85668739779956, 'eature_fraction': 0.5346043364366039, 'min_gain_to_split': 0.026722700167573943, 'lambda_11': 0.602948180106728, 'lambda_12': 0.01406998837192001}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:37,261] Trial 1491 finished with value: 7.85882212225558 and parameters: {'num_leaves': 108, 'min_data_in_leaf': 28, 'max_bin': 272, 'bagging_fraction': 0.866807508282269, 'eature_fraction': 0.5612016637537396, 'min_gain_to_split': 0.024148325123571186, 'lambda_11': 0.6890711853088201, 'lambda_12': 0.01727381338023904}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [85]	train's l2: 25.3699	valid's l2: 100.651
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [72]	train's l2: 26.4423	valid's l2: 98.0193
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:37,378] Trial 1492 finished with value: 7.966644715355199 and parameters: {'num_leaves': 134, 'min_data_in_leaf': 26, 'max_bin': 283, 'bagging_fraction': 0.8508196862819094, 'eature_fraction': 0.5980030997919259, 'min_gain_to_split': 0.03389594180035578, 'lambda_11': 0.8678243865009916, 'lambda_12': 0.028554400157999135}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:37,485] Trial 1493 finished with value: 7.786671713871124 and parameters: {'num_leaves': 149, 'min_data_in_leaf': 27, 'max_bin': 200, 'bagging_fraction': 0.86017197804194, 'eature_fraction': 0.5557726029128613, 'min_gain_to_split': 0.028708141535612013, 'lambda_11': 0.7605488693347179, 'lambda_12': 0.03600877811217058}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [72]	train's l2: 25.3108	valid's l2: 98.8234
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3872
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:37,585] Trial 1494 finished with value: 8.013542587456003 and parameters: {'num_leaves': 156, 'min_data_in_leaf': 26, 'max_bin': 209, 'bagging_fraction': 0.8710832592529005, 'eature_fraction': 0.5785872302948688, 'min_gain_to_split': 0.02145445823684299, 'lambda_11': 0.5653807123289137, 'lambda_12': 0.024453842837403497}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:37,711] Trial 1495 finished with value: 7.887708310138302 and parameters: {'num_leaves': 142, 'min_data_in_leaf': 30, 'max_bin': 217, 'bagging_fraction': 0.8627129205306426, 'eature_fraction': 0.5482514269371628, 'min_gain_to_split': 0.02527339936922395, 'lambda_11': 0.9062958238534845, 'lambda_12': 0.03167673771445474}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [62]	train's l2: 27.0249	valid's l2: 100.296
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [133]	train's l2: 20.9049	valid's l2: 99.1535
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:37,807] Trial 1496 finished with value: 7.958996705273715 and parameters: {'num_leaves': 161, 'min_data_in_leaf': 28, 'max_bin': 211, 'bagging_fraction': 0.854036541767835, 'eature_fraction': 0.5711242326260846, 'min_gain_to_split': 0.042714041281937065, 'lambda_11': 0.10667316347583673, 'lambda_12': 0.015047867854433086}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:37,905] Trial 1497 finished with value: 7.78664872446622 and parameters: {'num_leaves': 168, 'min_data_in_leaf': 27, 'max_bin': 291, 'bagging_fraction': 0.8681002387696872, 'eature_fraction': 0.56480193055491, 'min_gain_to_split': 0.02219175810709629, 'lambda_11': 0.6655763913216317, 'lambda_12': 0.012648122378122718}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [51]	train's l2: 30.3342	valid's l2: 100.385
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [68]	train's l2: 27.0999	valid's l2: 94.3871
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-03 08:45:38,011] Trial 1498 finished with value: 8.025798552690942 and parameters: {'num_leaves': 158, 'min_data_in_leaf': 27, 'max_bin': 221, 'bagging_fraction': 0.8573633083674161, 'eature_fraction': 0.6081478610592808, 'min_gain_to_split': 0.0310836161215635, 'lambda_11': 0.820148068499975, 'lambda_12': 0.010863438080880253}. Best is trial 868 with value: 7.785396231883049.
# [I 2024-09-03 08:45:38,117] Trial 1499 finished with value: 8.013536160944883 and parameters: {'num_leaves': 103, 'min_data_in_leaf': 26, 'max_bin': 204, 'bagging_fraction': 0.8603971049556794, 'eature_fraction': 0.5853346885726814, 'min_gain_to_split': 0.02736803699652553, 'lambda_11': 0.5344363258669853, 'lambda_12': 0.045058397731474534}. Best is trial 868 with value: 7.785396231883049.
# Early stopping, best iteration is:
# [68]	train's l2: 26.5078	valid's l2: 101.23
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [62]	train's l2: 27.0249	valid's l2: 100.295

# %%
trial = study.best_trial
print(f'trial {trial.number}')
print('MAE best: %.2f'% trial.value)
display(trial.params)
# Out:
# trial 868
# MAE best: 7.79
# {'num_leaves': 168,
#  'min_data_in_leaf': 27,
#  'max_bin': 219,
#  'bagging_fraction': 0.8587859327969419,
#  'eature_fraction': 0.5899201742517702,
#  'min_gain_to_split': 0.6042524986072988,
#  'lambda_11': 0.6998193447731732,
#  'lambda_12': 0.026416545210649976}

# %%
params_best = trial.params
params_best.update(params_base)
display(params_best)
# Out:
# {'num_leaves': 168,
#  'min_data_in_leaf': 27,
#  'max_bin': 219,
#  'bagging_fraction': 0.8587859327969419,
#  'eature_fraction': 0.5899201742517702,
#  'min_gain_to_split': 0.6042524986072988,
#  'lambda_11': 0.6998193447731732,
#  'lambda_12': 0.026416545210649976,
#  'objective': 'regression',
#  'metrics': 'mse',
#  'random_seed': 123,
#  'learnig_rate': 0.1,
#  'min_data_in_bin': 3,
#  'bagging_freq': 0,
#  'verbose': -1}

# %%
lgb_train = lgb.Dataset(x_tr, y_tr)
lgb_eval = lgb.Dataset(x_va, y_va, reference=lgb_train)

model = lgb.train(params_best,
                  lgb_train,
                  num_boost_round=500,
                  valid_sets=[lgb_train, lgb_eval],
                  valid_names=['train', 'valid'],
                  callbacks=[lgb.early_stopping(100),
                             lgb.log_evaluation(300)])

y_va_pred = model.predict(x_va,
                          num_iteration=model.best_iteration)

score = mean_absolute_error(y_va, y_va_pred)
print(f'MAE valid: {score:.2f}')
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [106]	train's l2: 19.675	valid's l2: 101.214
# MAE valid: 8.03

# %%
pred_lgb = model.predict(test_data_open, num_iteration=model.best_iteration)

# %%
# テストデータから閉店日を取得
test_data2 = test_data.reset_index(inplace=False, drop=True)
test_data2
test_data2[test_data2['close']==1].index
# Out:
# Index([137, 274, 275, 276, 277], dtype='int64')

# %%
submit = pd.DataFrame({'datetime' : test_data.index, 'pred' : y_test_pred})

print(submit)

# 閉店時の予測値を0に置き換える
for i in test_data2[test_data2['close']==1].index:
    submit['pred'].iloc[i] = 0
    
# 予測値を描画
plt.plot(submit['pred'])

submit.columns = submit.iloc[0]
print(submit)
submit.to_csv('ligthGBM_oputuna_0903_2.csv', index=False)
# Out:
#       datetime       pred
# 0   2016-04-01  66.407773
# 1   2016-04-02  67.271515
# 2   2016-04-03  66.566993
# 3   2016-04-04  73.312112
# 4   2016-04-05  59.999466
# ..         ...        ...
# 360 2017-03-27  77.724144
# 361 2017-03-28  77.724144
# 362 2017-03-29  79.838246
# 363 2017-03-30  84.539320
# 364 2017-03-31  77.566276
#
# [365 rows x 2 columns]
# 0   2016-04-01 00:00:00  66.407773
# 0            2016-04-01  66.407773
# 1            2016-04-02  67.271515
# 2            2016-04-03  66.566993
# 3            2016-04-04  73.312112
# 4            2016-04-05  59.999466
# ..                  ...        ...
# 360          2017-03-27  77.724144
# 361          2017-03-28  77.724144
# 362          2017-03-29  79.838246
# 363          2017-03-30  84.539320
# 364          2017-03-31  77.566276
#
# [365 rows x 2 columns]
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/128035164.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0

# %%
### XGBoost ###

import xgboost as xgb
regressor = xgb.XGBRegressor()
regressor.fit(x_tr.values, y_tr.values)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# 特徴量重要度（Feature Importances）
df_importance = pd.DataFrame(zip(x_tr.columns,
                                 regressor.feature_importances_),
                             columns=["Features","Importance"])
df_importance = df_importance.sort_values("Importance",
                                          ascending=False)
df_importance #確認
# Out:
#             Features  Importance
# 7          y_lag_365    0.284230
# 3              price    0.168052
# 4               year    0.122098
# 1           price_am    0.099351
# 13  price_pm_lag_365    0.078436
# 2           price_pm    0.067654
# 5              month    0.039875
# 11    price_pm_lag_1    0.025654
# 6            weekday    0.023308
# 8     price_am_lag_1    0.020810
# 10  price_am_lag_365    0.020621
# 9     price_am_lag_7    0.020612
# 12    price_pm_lag_7    0.015664
# 0             client    0.013634

# %%
# 予測
train_pred = regressor.predict(x_tr.values)
valid_pred = regressor.predict(x_va.values)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# 精度指標（テストデータ）
print('RMSE:')
print(np.sqrt(mean_squared_error(y_test, valid_pred)))
print('MAE:')
print(mean_absolute_error(y_test, valid_pred))
print('MAPE:')
print(mean_absolute_percentage_error(y_test, valid_pred))
# Out:
# RMSE:
# 10.934731517431167
# MAE:
# 8.636187874780942
# MAPE:
# 0.19143021731858223

# %%
# グラフ化
fig, ax = plt.subplots()
ax.plot(y_train.index, y_train.values, label="actual(train dataset)")
ax.plot(y_test.index, y_test.values, label="actual(test dataset)")
ax.plot(y_train.index, train_pred, linestyle="dotted", lw=2,color="m")
ax.plot(y_test.index, test_pred, label="XGBoost", linestyle="dotted", lw=2, color="m") 
plt.legend()

# %%
pred_xgb = regressor.predict(test_data_open.values)

submit_xgb = pd.DataFrame({'datetime' : test_data.index, 'pred' : pred_xgb})

# 閉店時の予測値を0に置き換える
for i in test_data2[test_data2['close']==1].index:
    submit_xgb['pred'].iloc[i] = 0

submit_xgb
# Out:
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
#       datetime       pred
# 0   2016-04-01  63.198486
# 1   2016-04-02  75.893250
# 2   2016-04-03  55.166782
# 3   2016-04-04  62.232346
# 4   2016-04-05  72.111298
# ..         ...        ...
# 360 2017-03-27  70.372025
# 361 2017-03-28  71.345116
# 362 2017-03-29  81.478096
# 363 2017-03-30  90.237473
# 364 2017-03-31  67.121292
#
# [365 rows x 2 columns]

# %%
# 平均をとってアンサンブル
submit_ensemble = pd.DataFrame({'datetime' : test_data.index, 'pred' : ((pred_lgb) + (pred_lgb)) / 2})

# %%
submit_ensemble
# Out:
#       datetime       pred
# 0   2016-04-01  66.407773
# 1   2016-04-02  67.271515
# 2   2016-04-03  66.566993
# 3   2016-04-04  73.312112
# 4   2016-04-05  59.999466
# ..         ...        ...
# 360 2017-03-27  77.724144
# 361 2017-03-28  77.724144
# 362 2017-03-29  79.838246
# 363 2017-03-30  84.539320
# 364 2017-03-31  77.566276
#
# [365 rows x 2 columns]

# %%
submit_ensemble.to_csv('ensemble_0903_1.csv', index=False)
