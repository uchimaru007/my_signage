# %%
import pandas as pd
import numpy as np

import ruptures as rpt
from ruptures.metrics import precision_recall
import matplotlib.pyplot as plt

import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error

import lightgbm as lgb
import seaborn as sns

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = [12, 9]

# %%
import holidays

# %%
df = pd.read_csv('/Users/estyle-150/github/my_signage/data/processed/processed20240826.csv')
df['datetime'] = pd.to_datetime(df['datetime'])
df.set_index('datetime', inplace=True)
df
# Out:
#              y  client  close  price_am  price_pm  is_train     price  year  \
# datetime
# 2010-07-01  17       0      0  0.192308  0.076923         1  0.134615  2010
# 2010-07-02  18       0      0  0.692308  0.423077         1  0.557692  2010
# 2010-07-03  20       0      0  1.807692  1.192308         1  1.500000  2010
# 2010-07-04  20       0      0  1.407407  0.925926         1  1.166667  2010
# 2010-07-05  14       0      0  0.346154  0.192308         1  0.269231  2010
# ...         ..     ...    ...       ...       ...       ...       ...   ...
# 2017-03-27   0       0      0  5.000000  4.000000         0  4.500000  2017
# 2017-03-28   0       0      0  4.000000  4.000000         0  4.000000  2017
# 2017-03-29   0       0      0  3.000000  3.000000         0  3.000000  2017
# 2017-03-30   0       0      0  4.000000  3.000000         0  3.500000  2017
# 2017-03-31   0       1      0  5.000000  4.000000         0  4.500000  2017
#
#             month  weekday  ...  price_am_lag_7  price_am_lag_365  \
# datetime                    ...
# 2010-07-01      7        3  ...             NaN               NaN
# 2010-07-02      7        4  ...             NaN               NaN
# 2010-07-03      7        5  ...             NaN               NaN
# 2010-07-04      7        6  ...             NaN               NaN
# 2010-07-05      7        0  ...             NaN               NaN
# ...           ...      ...  ...             ...               ...
# 2017-03-27      3        0  ...             3.0               5.0
# 2017-03-28      3        1  ...             4.0               4.0
# 2017-03-29      3        2  ...             2.0               4.0
# 2017-03-30      3        3  ...             3.0               5.0
# 2017-03-31      3        4  ...             4.0               5.0
#
#             price_pm_lag_1  price_pm_lag_7  price_pm_lag_365  \
# datetime
# 2010-07-01             NaN             NaN               NaN
# 2010-07-02        0.076923             NaN               NaN
# 2010-07-03        0.423077             NaN               NaN
# 2010-07-04        1.192308             NaN               NaN
# 2010-07-05        0.925926             NaN               NaN
# ...                    ...             ...               ...
# 2017-03-27        4.000000             4.0               4.0
# 2017-03-28        4.000000             4.0               4.0
# 2017-03-29        4.000000             4.0               4.0
# 2017-03-30        3.000000             2.0               4.0
# 2017-03-31        3.000000             5.0               4.0
#
#             price_am_moving_avg_7  price_am_moving_avg_30  \
# datetime
# 2010-07-01                    NaN                     NaN
# 2010-07-02                    NaN                     NaN
# 2010-07-03                    NaN                     NaN
# 2010-07-04                    NaN                     NaN
# 2010-07-05                    NaN                     NaN
# ...                           ...                     ...
# 2017-03-27               3.857143                2.166667
# 2017-03-28               3.857143                2.233333
# 2017-03-29               4.000000                2.266667
# 2017-03-30               4.142857                2.333333
# 2017-03-31               4.285714                2.433333
#
#             price_pm_moving_avg_7  price_pm_moving_avg_30  day
# datetime
# 2010-07-01                    NaN                     NaN    1
# 2010-07-02                    NaN                     NaN    2
# 2010-07-03                    NaN                     NaN    3
# 2010-07-04                    NaN                     NaN    4
# 2010-07-05                    NaN                     NaN    5
# ...                           ...                     ...  ...
# 2017-03-27               4.000000                2.166667   27
# 2017-03-28               4.000000                2.233333   28
# 2017-03-29               3.857143                2.266667   29
# 2017-03-30               4.000000                2.300000   30
# 2017-03-31               3.857143                2.400000   31
#
# [2466 rows x 22 columns]

# %%
pd.DataFrame(df.columns)
# Out:
#                          0
# 0                        y
# 1                   client
# 2                    close
# 3                 price_am
# 4                 price_pm
# 5                 is_train
# 6                    price
# 7                     year
# 8                    month
# 9                  weekday
# 10               y_lag_365
# 11          price_am_lag_1
# 12          price_am_lag_7
# 13        price_am_lag_365
# 14          price_pm_lag_1
# 15          price_pm_lag_7
# 16        price_pm_lag_365
# 17   price_am_moving_avg_7
# 18  price_am_moving_avg_30
# 19   price_pm_moving_avg_7
# 20  price_pm_moving_avg_30
# 21                     day

# %%
# 使用するカラム
list_no = [0, 1, 2, 3, 4, 5, 7, 8, 9, 10]
use_list = [df.columns[i] for i in list_no]

# %%
################
### 変化点検知 ###
################

# コスト関数の設定
model = "l2"
# アルゴの設定と学習
algo = rpt.Dynp(model=model).fit(df[['y']])
# 変化点の検出
my_bkps = algo.predict(n_bkps=3)
# 結果のプロット
rpt.show.display(df[['y']], my_bkps, figsize=(12, 9))
plt.show()
# 検出された変化点
print(my_bkps)
# Out:
# [600, 2060, 2100, 2466]

# %%
#df = df[my_bkps[0]:]
df = df[use_list]

# %%
# 訓練データをとる
train_data = df[df['is_train'] == 1].copy()

# テストデータをとる
test_data = df[df['is_train'] == 0].copy()

# 訓練データから不要な列（'is_train'）を削除
train_data.drop(['is_train'], axis=1, inplace=True)

# テストデータから不要な列を削除
test_data.drop(['y','is_train'], axis=1, inplace=True)

# テストデータからcloseを削除（このデータで予測する）
test_data_open = test_data.drop(['close'], axis=1, inplace=False)

display(train_data.head(), test_data.head())


plt.plot(df['y'])
# Out:
#              y  client  close  price_am  price_pm  year  month  weekday  \
# datetime
# 2010-07-01  17       0      0  0.192308  0.076923  2010      7        3
# 2010-07-02  18       0      0  0.692308  0.423077  2010      7        4
# 2010-07-03  20       0      0  1.807692  1.192308  2010      7        5
# 2010-07-04  20       0      0  1.407407  0.925926  2010      7        6
# 2010-07-05  14       0      0  0.346154  0.192308  2010      7        0
#
#             y_lag_365
# datetime
# 2010-07-01        NaN
# 2010-07-02        NaN
# 2010-07-03        NaN
# 2010-07-04        NaN
# 2010-07-05        NaN
#             client  close  price_am  price_pm  year  month  weekday  y_lag_365
# datetime
# 2016-04-01       1      0       3.0       2.0  2016      4        4       60.0
# 2016-04-02       0      0       5.0       5.0  2016      4        5       75.0
# 2016-04-03       1      0       2.0       2.0  2016      4        6       86.0
# 2016-04-04       1      0       1.0       1.0  2016      4        0       69.0
# 2016-04-05       0      0       1.0       1.0  2016      4        1       61.0

# %%
# 訓練データから閉店時のデータを削除（これを学習させる）
train_data_open =  train_data[train_data['close']==0]
train_data_open_2 = train_data_open.drop(['close'], axis=1, inplace=False)

#print(len(train_data_open_2))
#print(len(train_data))

# %%
from sklearn.model_selection import KFold
import optuna.integration.lightgbm as lgb_op
from sklearn.model_selection import train_test_split
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_squared_error


# 訓練データと検証データに分ける
N = 30
X_train = train_data_open_2.drop(['y'], axis=1)[:-N]
y_train = train_data_open_2['y'][:-N]

X_test = train_data_open_2.drop(['y'], axis=1)[-N:]
y_test = train_data_open_2['y'][-N:]

# LightGBM用のデータセット
lgb_train = lgb.Dataset(X_train, y_train)
lgb_test = lgb.Dataset(X_test, y_test)

# 評価基準 
params = {"objective" : "regression", 
              "metric" : "mse", 
              "num_leaves" : 7,
              "early_stopping_rounds" : 30,
              "verbosity": -1}

# 回帰モデル作成
model = lgb.train(params, lgb_train, valid_sets=lgb_test)

# 予測
test_pred = model.predict(X_test)
pred_df = pd.concat([y_test.reset_index(drop=True), pd.Series(test_pred)], axis = 1)
    
pred_df.columns = ['true', 'pred']
pred_df

mse = mean_squared_error(y_test, test_pred)
print('MSE:',round(mse,3))
# Out:
# MSE: 88.037

# %%
importances = model.feature_importance(importance_type='gain')
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(8,4))
plt.title('feature importance')
plt.bar(range(len(indices)), importances[indices])
plt.xticks(range(len(indices)), train_data_open_2.columns[indices], rotation=90)
# Out:
# ([<matplotlib.axis.XTick at 0x15feddd90>,
#   <matplotlib.axis.XTick at 0x15fe07ce0>,
#   <matplotlib.axis.XTick at 0x15fedd640>,
#   <matplotlib.axis.XTick at 0x15ff0deb0>,
#   <matplotlib.axis.XTick at 0x15ff0d7f0>,
#   <matplotlib.axis.XTick at 0x15ff0edb0>,
#   <matplotlib.axis.XTick at 0x15ff0f6b0>],
#  [Text(0, 0, 'weekday'),
#   Text(1, 0, 'client'),
#   Text(2, 0, 'price_pm'),
#   Text(3, 0, 'price_am'),
#   Text(4, 0, 'year'),
#   Text(5, 0, 'month'),
#   Text(6, 0, 'y')])

# %%
# 可視化
plt.plot(pred_df)
# Out:
# [<matplotlib.lines.Line2D at 0x15fec8f50>,
#  <matplotlib.lines.Line2D at 0x15ff48770>]

# %%
train_data[train_data['close']==1]
# Out:
#             y  client  close  price_am  price_pm  year  month  weekday  \
# datetime
# 2010-12-31  0       0      1  0.692308  0.538462  2010     12        4
# 2011-01-01  0       0      1  0.892857  0.464286  2011      1        5
# 2011-01-02  0       0      1  0.428571  0.250000  2011      1        6
# 2011-01-03  0       0      1  0.142857  0.000000  2011      1        0
# 2011-12-31  0       0      1  1.600000  1.240000  2011     12        5
# 2012-01-01  0       0      1  0.428571  0.250000  2012      1        6
# 2012-01-02  0       0      1  0.142857  0.000000  2012      1        0
# 2012-01-03  0       0      1  0.107143  0.071429  2012      1        1
# 2012-12-31  0       0      1  0.384615  0.269231  2012     12        0
# 2013-01-01  0       0      1  0.107143  0.071429  2013      1        1
# 2013-01-02  0       0      1  0.035714  0.000000  2013      1        2
# 2013-01-03  0       0      1  0.178571  0.107143  2013      1        3
# 2013-08-12  0       0      1  0.153846  0.038462  2013      8        0
# 2013-12-31  0       0      1  0.346154  0.153846  2013     12        1
# 2014-01-01  0       0      1  0.035714  0.000000  2014      1        2
# 2014-01-02  0       0      1  0.178571  0.107143  2014      1        3
# 2014-01-03  0       0      1  0.285714  0.178571  2014      1        4
# 2014-08-12  0       0      1  0.083333  0.041667  2014      8        1
# 2014-12-31  0       0      1  0.040000  0.000000  2014     12        2
# 2015-01-01  0       0      1  0.178571  0.107143  2015      1        3
# 2015-01-02  0       0      1  0.285714  0.178571  2015      1        4
# 2015-01-03  0       0      1  0.892857  0.464286  2015      1        5
# 2015-08-12  0       0      1  0.076923  0.076923  2015      8        2
# 2015-12-31  0       0      1  0.269231  0.115385  2015     12        3
# 2016-01-01  0       0      1  0.285714  0.178571  2016      1        4
# 2016-01-02  0       0      1  0.892857  0.464286  2016      1        5
# 2016-01-03  0       0      1  0.428571  0.250000  2016      1        6
#
#             y_lag_365
# datetime
# 2010-12-31        NaN
# 2011-01-01        NaN
# 2011-01-02        NaN
# 2011-01-03        NaN
# 2011-12-31        0.0
# 2012-01-01        0.0
# 2012-01-02        0.0
# 2012-01-03        0.0
# 2012-12-31        0.0
# 2013-01-01        0.0
# 2013-01-02        0.0
# 2013-01-03       12.0
# 2013-08-12       14.0
# 2013-12-31        0.0
# 2014-01-01        0.0
# 2014-01-02        0.0
# 2014-01-03        0.0
# 2014-08-12        0.0
# 2014-12-31        0.0
# 2015-01-01        0.0
# 2015-01-02        0.0
# 2015-01-03        0.0
# 2015-08-12        0.0
# 2015-12-31        0.0
# 2016-01-01        0.0
# 2016-01-02        0.0
# 2016-01-03        0.0

# %%
# oputunaによるハイパーパラメータのチューニング
import optuna

# %%
x_tr = X_train
x_va = X_test
y_tr = y_train
y_va = y_test

# %%
# 固定値のハイパーパラメータ
params_base = {
    'objective' : 'regression',
    'metrics' : 'mse',
    'random_seed' : 123,    
    'learnig_rate' : 0.1,  # １回のブースティングで加算する重みの比率
    'min_data_in_bin' : 3,  # ヒストグラムの１つのbinに含まれる最小のレコード数
    'bagging_freq' : 0,
    'verbose' : -1,
}


# ハイパーパラメータの探索範囲
def objective(trial):
    params_turning = {
        'num_leaves' : trial.suggest_int('num_leaves', 50, 200),
        'min_data_in_leaf' : trial.suggest_int('min_data_in_leaf', 2, 30),
        'max_bins' : trial.suggest_int('max_bin', 200, 400),
        'bagging_fraction' : trial.suggest_float('bagging_fraction', 0.8, 0.95),
        'feature_fraction' : trial.suggest_float('eature_fraction', 0.35, 0.65),
        'min_gain_to_split' : trial.suggest_float('min_gain_to_split', 0.01, 1, log=True),
        'lambda_11' : trial.suggest_float('lambda_11', 0.01, 1, log=True),
        'lambda_12' : trial.suggest_float('lambda_12', 0.01, 1, log=True),
    }
    
    # 探索用ハイパーパラメータの設定
    params_turning.update(params_base)
    lgb_train = lgb.Dataset(x_tr, y_tr)
    lgb_eval = lgb.Dataset(x_va, y_va)

    #探索用ハイパーパラメータで学習
    model = lgb.train(params_turning,
                      lgb_train,
                      num_boost_round=6000,
                      valid_sets=[lgb_train, lgb_eval],
                      valid_names=['train', 'valid'],
                      callbacks=[lgb.early_stopping(50),
                                 lgb.log_evaluation(500)])
    y_va_pred = model.predict(x_va,
                              num_iteration=model.best_iteration)
    score = mean_absolute_error(y_va, y_va_pred)
    print('')
    return score

# %%
# ハイパーパラメータの最適化の実行
study = optuna.create_study(sampler=optuna.samplers.TPESampler(seed=0), direction='minimize')
study.optimize(objective, n_trials=1500)
# Out:
# [I 2024-09-06 17:02:20,085] A new study created in memory with name: no-name-92a58117-d78a-46b2-a259-183661e3510d
# [I 2024-09-06 17:02:20,175] Trial 0 finished with value: 7.246547828922702 and parameters: {'num_leaves': 132, 'min_data_in_leaf': 22, 'max_bin': 321, 'bagging_fraction': 0.8817324774495345, 'eature_fraction': 0.47709643980167143, 'min_gain_to_split': 0.19578897201212997, 'lambda_11': 0.07501954443620121, 'lambda_12': 0.6074996073425692}. Best is trial 0 with value: 7.246547828922702.
# [I 2024-09-06 17:02:20,269] Trial 1 finished with value: 6.768124565254109 and parameters: {'num_leaves': 195, 'min_data_in_leaf': 13, 'max_bin': 359, 'bagging_fraction': 0.8793342379629356, 'eature_fraction': 0.5204133683281797, 'min_gain_to_split': 0.70989362574059, 'lambda_11': 0.013869861245357327, 'lambda_12': 0.014936835544198456}. Best is trial 1 with value: 6.768124565254109.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	train's l2: 34.5596	valid's l2: 83.4403
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [83]	train's l2: 24.7762	valid's l2: 73.4922
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:20,349] Trial 2 finished with value: 7.754661865583353 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 26, 'max_bin': 356, 'bagging_fraction': 0.9305018222370228, 'eature_fraction': 0.6435855026698292, 'min_gain_to_split': 0.3965675081771009, 'lambda_11': 0.08374496868436809, 'lambda_12': 0.36396393567863894}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:20,431] Trial 3 finished with value: 7.35805977202337 and parameters: {'num_leaves': 67, 'min_data_in_leaf': 20, 'max_bin': 228, 'bagging_fraction': 0.9417003375574375, 'eature_fraction': 0.5065544965250215, 'min_gain_to_split': 0.06750312521595925, 'lambda_11': 0.0338151426782029, 'lambda_12': 0.35356346291488117}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:20,518] Trial 4 finished with value: 6.997008513559937 and parameters: {'num_leaves': 118, 'min_data_in_leaf': 18, 'max_bin': 203, 'bagging_fraction': 0.8926453245613816, 'eature_fraction': 0.5336287168167264, 'min_gain_to_split': 0.17134364197119656, 'lambda_11': 0.7717846862118064, 'lambda_12': 0.2310152225018237}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [80]	train's l2: 31.6391	valid's l2: 91.4105
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [89]	train's l2: 29.7686	valid's l2: 86.7532
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 29.2675	valid's l2: 77.3999
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:20,632] Trial 5 finished with value: 7.189212144589683 and parameters: {'num_leaves': 104, 'min_data_in_leaf': 14, 'max_bin': 340, 'bagging_fraction': 0.8090338207443906, 'eature_fraction': 0.5500300146337003, 'min_gain_to_split': 0.21941976179005757, 'lambda_11': 0.02634905974115613, 'lambda_12': 0.018107254066631072}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:20,727] Trial 6 finished with value: 7.388382363291165 and parameters: {'num_leaves': 97, 'min_data_in_leaf': 12, 'max_bin': 314, 'bagging_fraction': 0.865790227019348, 'eature_fraction': 0.6465121514177679, 'min_gain_to_split': 0.015998881492631498, 'lambda_11': 0.02616697456085447, 'lambda_12': 0.021019338091154416}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [83]	train's l2: 25.4288	valid's l2: 77.3565
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [61]	train's l2: 24.093	valid's l2: 81.6567
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:20,853] Trial 7 finished with value: 7.267408805114834 and parameters: {'num_leaves': 148, 'min_data_in_leaf': 9, 'max_bin': 293, 'bagging_fraction': 0.8366638388002404, 'eature_fraction': 0.3976908750936559, 'min_gain_to_split': 0.016624564693643644, 'lambda_11': 0.2054277828628595, 'lambda_12': 0.018895826938026012}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:20,951] Trial 8 finished with value: 6.813709757022504 and parameters: {'num_leaves': 79, 'min_data_in_leaf': 12, 'max_bin': 365, 'bagging_fraction': 0.8145651913689592, 'eature_fraction': 0.6013834722496412, 'min_gain_to_split': 0.015566709318481201, 'lambda_11': 0.8972612866432508, 'lambda_12': 0.08655704137361815}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:21,021] Trial 9 finished with value: 7.368441385781854 and parameters: {'num_leaves': 197, 'min_data_in_leaf': 19, 'max_bin': 348, 'bagging_fraction': 0.8058781688381481, 'eature_fraction': 0.43484208877292285, 'min_gain_to_split': 0.017393745944806985, 'lambda_11': 0.0391093317225106, 'lambda_12': 0.0172764870082179}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [87]	train's l2: 25.185	valid's l2: 79.0474
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [88]	train's l2: 24.3838	valid's l2: 73.8301
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 34.7693	valid's l2: 83.7026
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:21,175] Trial 10 finished with value: 9.252531930390004 and parameters: {'num_leaves': 195, 'min_data_in_leaf': 3, 'max_bin': 391, 'bagging_fraction': 0.9084065267120113, 'eature_fraction': 0.35831680797439047, 'min_gain_to_split': 0.9510758272467729, 'lambda_11': 0.012438875955963435, 'lambda_12': 0.07916048790686309}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:21,333] Trial 11 finished with value: 8.446224081286266 and parameters: {'num_leaves': 167, 'min_data_in_leaf': 7, 'max_bin': 390, 'bagging_fraction': 0.8498329522455423, 'eature_fraction': 0.5915466403322428, 'min_gain_to_split': 0.06318611516210731, 'lambda_11': 0.6732083881543502, 'lambda_12': 0.058124160400173014}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [81]	train's l2: 19.7115	valid's l2: 125.883
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 16.6322	valid's l2: 109.727
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:21,456] Trial 12 finished with value: 6.851671372620592 and parameters: {'num_leaves': 76, 'min_data_in_leaf': 11, 'max_bin': 268, 'bagging_fraction': 0.8338390023579931, 'eature_fraction': 0.5872576144178007, 'min_gain_to_split': 0.0328616173682592, 'lambda_11': 0.22718246572845402, 'lambda_12': 0.04128048990405015}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:21,588] Trial 13 finished with value: 9.876018879398064 and parameters: {'num_leaves': 170, 'min_data_in_leaf': 5, 'max_bin': 368, 'bagging_fraction': 0.8606449404802545, 'eature_fraction': 0.58559941302925, 'min_gain_to_split': 0.9388287242054529, 'lambda_11': 0.010844293740159572, 'lambda_12': 0.13252479388025248}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [102]	train's l2: 22.2417	valid's l2: 74.4042
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [110]	train's l2: 14.9771	valid's l2: 142.238
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:21,684] Trial 14 finished with value: 7.144269139458453 and parameters: {'num_leaves': 90, 'min_data_in_leaf': 16, 'max_bin': 286, 'bagging_fraction': 0.909225842769227, 'eature_fraction': 0.47683556769594976, 'min_gain_to_split': 0.42943856658548824, 'lambda_11': 0.3294870521361328, 'lambda_12': 0.033350638031589996}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:21,811] Trial 15 finished with value: 6.899417088616628 and parameters: {'num_leaves': 130, 'min_data_in_leaf': 14, 'max_bin': 375, 'bagging_fraction': 0.8260345623933, 'eature_fraction': 0.553256272665839, 'min_gain_to_split': 0.036565206858587926, 'lambda_11': 0.14308248328114823, 'lambda_12': 0.010813279908977303}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [91]	train's l2: 30.9815	valid's l2: 77.6734
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [100]	train's l2: 23.2541	valid's l2: 76.8746
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:21,918] Trial 16 finished with value: 7.552836103447601 and parameters: {'num_leaves': 166, 'min_data_in_leaf': 25, 'max_bin': 330, 'bagging_fraction': 0.8840458753831157, 'eature_fraction': 0.6087651018902488, 'min_gain_to_split': 0.10343272083950615, 'lambda_11': 0.4156739404762543, 'lambda_12': 0.14252197968259814}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:22,074] Trial 17 finished with value: 7.334219486759898 and parameters: {'num_leaves': 150, 'min_data_in_leaf': 9, 'max_bin': 398, 'bagging_fraction': 0.903668943079996, 'eature_fraction': 0.511738370285111, 'min_gain_to_split': 0.01099204432345524, 'lambda_11': 0.05833381149221135, 'lambda_12': 0.7325894753516439}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [102]	train's l2: 31.0725	valid's l2: 89.8931
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [83]	train's l2: 19.1504	valid's l2: 82.6992
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:22,147] Trial 18 finished with value: 7.852147912671799 and parameters: {'num_leaves': 110, 'min_data_in_leaf': 29, 'max_bin': 365, 'bagging_fraction': 0.8487656385607285, 'eature_fraction': 0.4555003787715459, 'min_gain_to_split': 0.48816485940075605, 'lambda_11': 0.9357600818033166, 'lambda_12': 0.01007312763167237}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:22,237] Trial 19 finished with value: 9.836066626112647 and parameters: {'num_leaves': 81, 'min_data_in_leaf': 2, 'max_bin': 268, 'bagging_fraction': 0.8196968419301689, 'eature_fraction': 0.6215230338768319, 'min_gain_to_split': 0.031901634991102774, 'lambda_11': 0.017167478956060873, 'lambda_12': 0.0405864394234084}. Best is trial 1 with value: 6.768124565254109.
# Early stopping, best iteration is:
# [91]	train's l2: 37.7155	valid's l2: 95.65
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	train's l2: 22.4383	valid's l2: 139.263
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [73]	train's l2: 27.8896	valid's l2: 76.3235
# [I 2024-09-06 17:02:22,344] Trial 20 finished with value: 7.018778189022377 and parameters: {'num_leaves': 178, 'min_data_in_leaf': 15, 'max_bin': 309, 'bagging_fraction': 0.8720696634678227, 'eature_fraction': 0.5548696968344823, 'min_gain_to_split': 0.11234802065585472, 'lambda_11': 0.1353240951782776, 'lambda_12': 0.09104533074096866}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:22,428] Trial 21 finished with value: 7.075074806703807 and parameters: {'num_leaves': 73, 'min_data_in_leaf': 11, 'max_bin': 262, 'bagging_fraction': 0.8317884258154532, 'eature_fraction': 0.5725808007099005, 'min_gain_to_split': 0.033092913569979746, 'lambda_11': 0.4753072418244358, 'lambda_12': 0.035228351968922475}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:22,511] Trial 22 finished with value: 7.083721681678558 and parameters: {'num_leaves': 50, 'min_data_in_leaf': 11, 'max_bin': 249, 'bagging_fraction': 0.800747623886586, 'eature_fraction': 0.6145013659876774, 'min_gain_to_split': 0.02327708443231153, 'lambda_11': 0.3119883128159587, 'lambda_12': 0.05528409960786219}. Best is trial 1 with value: 6.768124565254109.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [57]	train's l2: 29.1667	valid's l2: 76.4742
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	train's l2: 26.0032	valid's l2: 76.5012
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:22,600] Trial 23 finished with value: 8.685158365233375 and parameters: {'num_leaves': 68, 'min_data_in_leaf': 7, 'max_bin': 282, 'bagging_fraction': 0.8475461458934338, 'eature_fraction': 0.5245771206360272, 'min_gain_to_split': 0.044680381653189695, 'lambda_11': 0.20007159708970632, 'lambda_12': 0.029222076071223395}. Best is trial 1 with value: 6.768124565254109.
# [I 2024-09-06 17:02:22,714] Trial 24 finished with value: 6.717909873773002 and parameters: {'num_leaves': 90, 'min_data_in_leaf': 12, 'max_bin': 239, 'bagging_fraction': 0.81736853199644, 'eature_fraction': 0.5721769399273705, 'min_gain_to_split': 0.011762350710159327, 'lambda_11': 0.22250499012541486, 'lambda_12': 0.05954356591810424}. Best is trial 24 with value: 6.717909873773002.
# Early stopping, best iteration is:
# [58]	train's l2: 27.0934	valid's l2: 110.81
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	train's l2: 23.81	valid's l2: 72.0961
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:22,841] Trial 25 finished with value: 7.285045274627842 and parameters: {'num_leaves': 118, 'min_data_in_leaf': 17, 'max_bin': 229, 'bagging_fraction': 0.8193765496632084, 'eature_fraction': 0.566327980037316, 'min_gain_to_split': 0.012567289628717542, 'lambda_11': 0.5566195758147405, 'lambda_12': 0.14296624277181033}. Best is trial 24 with value: 6.717909873773002.
# [I 2024-09-06 17:02:22,942] Trial 26 finished with value: 7.1103317093153615 and parameters: {'num_leaves': 88, 'min_data_in_leaf': 13, 'max_bin': 336, 'bagging_fraction': 0.857767600010063, 'eature_fraction': 0.5346194537041119, 'min_gain_to_split': 0.061913803191561444, 'lambda_11': 0.13280252925312114, 'lambda_12': 0.23582861706083266}. Best is trial 24 with value: 6.717909873773002.
# Early stopping, best iteration is:
# [96]	train's l2: 26.5857	valid's l2: 83.9386
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 25.2056	valid's l2: 79.9131
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:23,130] Trial 27 finished with value: 7.277260897248278 and parameters: {'num_leaves': 138, 'min_data_in_leaf': 8, 'max_bin': 202, 'bagging_fraction': 0.8142564638253897, 'eature_fraction': 0.4739457133987566, 'min_gain_to_split': 0.022240331145532553, 'lambda_11': 0.046804769627807205, 'lambda_12': 0.059558498947115096}. Best is trial 24 with value: 6.717909873773002.
# [I 2024-09-06 17:02:23,232] Trial 28 finished with value: 9.59750772997293 and parameters: {'num_leaves': 60, 'min_data_in_leaf': 5, 'max_bin': 360, 'bagging_fraction': 0.8425126124285445, 'eature_fraction': 0.6255008821934425, 'min_gain_to_split': 0.011376661662490727, 'lambda_11': 0.016446309375618865, 'lambda_12': 0.11337497385820652}. Best is trial 24 with value: 6.717909873773002.
# [I 2024-09-06 17:02:23,310] Trial 29 finished with value: 7.078791224263872 and parameters: {'num_leaves': 99, 'min_data_in_leaf': 16, 'max_bin': 385, 'bagging_fraction': 0.8797570570387403, 'eature_fraction': 0.49288030869384236, 'min_gain_to_split': 0.2568749819835293, 'lambda_11': 0.06357604415507585, 'lambda_12': 0.0758890535129704}. Best is trial 24 with value: 6.717909873773002.
# Early stopping, best iteration is:
# [81]	train's l2: 25.3498	valid's l2: 78.9108
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	train's l2: 20.8863	valid's l2: 138.977
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 32.8961	valid's l2: 77.2258
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:23,413] Trial 30 finished with value: 7.630040104559304 and parameters: {'num_leaves': 83, 'min_data_in_leaf': 22, 'max_bin': 322, 'bagging_fraction': 0.8920923938715749, 'eature_fraction': 0.5944343286687734, 'min_gain_to_split': 0.15717485665483993, 'lambda_11': 0.08520355178813388, 'lambda_12': 0.025513228311898426}. Best is trial 24 with value: 6.717909873773002.
# [I 2024-09-06 17:02:23,518] Trial 31 finished with value: 7.214976209571361 and parameters: {'num_leaves': 77, 'min_data_in_leaf': 10, 'max_bin': 242, 'bagging_fraction': 0.8285427291439577, 'eature_fraction': 0.5788174666025739, 'min_gain_to_split': 0.021487517079601774, 'lambda_11': 0.23281344456208283, 'lambda_12': 0.045609762728832624}. Best is trial 24 with value: 6.717909873773002.
# [I 2024-09-06 17:02:23,605] Trial 32 finished with value: 7.299444661097097 and parameters: {'num_leaves': 62, 'min_data_in_leaf': 12, 'max_bin': 273, 'bagging_fraction': 0.8000153129268532, 'eature_fraction': 0.6066370598510485, 'min_gain_to_split': 0.025631179601255088, 'lambda_11': 0.27515008235640875, 'lambda_12': 0.01335160741373777}. Best is trial 24 with value: 6.717909873773002.
# Early stopping, best iteration is:
# [99]	train's l2: 29.7898	valid's l2: 86.8725
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 24.085	valid's l2: 79.9551
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	train's l2: 27.5083	valid's l2: 79.2997
# [I 2024-09-06 17:02:23,700] Trial 33 finished with value: 6.984386882170868 and parameters: {'num_leaves': 91, 'min_data_in_leaf': 14, 'max_bin': 254, 'bagging_fraction': 0.9219034268971428, 'eature_fraction': 0.6349619787407847, 'min_gain_to_split': 0.010093608638271431, 'lambda_11': 0.16179519949958795, 'lambda_12': 0.18528816104425808}. Best is trial 24 with value: 6.717909873773002.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [67]	train's l2: 28.2279	valid's l2: 74.3433
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [126]	train's l2: 26.744	valid's l2: 85.1696
# [I 2024-09-06 17:02:23,824] Trial 34 finished with value: 7.494877253002938 and parameters: {'num_leaves': 113, 'min_data_in_leaf': 21, 'max_bin': 220, 'bagging_fraction': 0.8168598933183213, 'eature_fraction': 0.5422176355012753, 'min_gain_to_split': 0.01589357166069363, 'lambda_11': 0.39279191003185226, 'lambda_12': 0.047789029728244926}. Best is trial 24 with value: 6.717909873773002.
# [I 2024-09-06 17:02:23,905] Trial 35 finished with value: 6.69032285966428 and parameters: {'num_leaves': 57, 'min_data_in_leaf': 12, 'max_bin': 301, 'bagging_fraction': 0.8244577997923188, 'eature_fraction': 0.517043887322631, 'min_gain_to_split': 0.6314531807446238, 'lambda_11': 0.11836938368078254, 'lambda_12': 0.41369853282056623}. Best is trial 35 with value: 6.69032285966428.
# [I 2024-09-06 17:02:23,985] Trial 36 finished with value: 7.209631890186135 and parameters: {'num_leaves': 54, 'min_data_in_leaf': 18, 'max_bin': 351, 'bagging_fraction': 0.9464570814248118, 'eature_fraction': 0.4991674994796768, 'min_gain_to_split': 0.6388202274833972, 'lambda_11': 0.097164042445493, 'lambda_12': 0.5409240957549232}. Best is trial 35 with value: 6.69032285966428.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [70]	train's l2: 29.5161	valid's l2: 72.6157
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	train's l2: 33.6975	valid's l2: 81.2378
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:24,078] Trial 37 finished with value: 6.8104600500254815 and parameters: {'num_leaves': 67, 'min_data_in_leaf': 13, 'max_bin': 303, 'bagging_fraction': 0.8241333657569635, 'eature_fraction': 0.5271911405114731, 'min_gain_to_split': 0.28900478037892374, 'lambda_11': 0.9811862268651028, 'lambda_12': 0.36299139803687386}. Best is trial 35 with value: 6.69032285966428.
# [I 2024-09-06 17:02:24,162] Trial 38 finished with value: 6.748429371895925 and parameters: {'num_leaves': 56, 'min_data_in_leaf': 15, 'max_bin': 298, 'bagging_fraction': 0.8654089892890282, 'eature_fraction': 0.4562944428303823, 'min_gain_to_split': 0.33623900429420056, 'lambda_11': 0.029924636999673373, 'lambda_12': 0.4270336889227054}. Best is trial 35 with value: 6.69032285966428.
# [I 2024-09-06 17:02:24,239] Trial 39 finished with value: 7.3121198754873395 and parameters: {'num_leaves': 58, 'min_data_in_leaf': 16, 'max_bin': 216, 'bagging_fraction': 0.8684135924078247, 'eature_fraction': 0.42808332270813204, 'min_gain_to_split': 0.6643717987969053, 'lambda_11': 0.02841123300784853, 'lambda_12': 0.47757908490575907}. Best is trial 35 with value: 6.69032285966428.
# Early stopping, best iteration is:
# [73]	train's l2: 28.0364	valid's l2: 72.1173
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	train's l2: 32.4488	valid's l2: 74.9172
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 33.84	valid's l2: 82.2258
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:24,335] Trial 40 finished with value: 7.186886326785481 and parameters: {'num_leaves': 187, 'min_data_in_leaf': 20, 'max_bin': 294, 'bagging_fraction': 0.8907953056643926, 'eature_fraction': 0.45229581145874753, 'min_gain_to_split': 0.33325813937815146, 'lambda_11': 0.019757720401873746, 'lambda_12': 0.2611703115215322}. Best is trial 35 with value: 6.69032285966428.
# [I 2024-09-06 17:02:24,427] Trial 41 finished with value: 6.425571722194169 and parameters: {'num_leaves': 63, 'min_data_in_leaf': 13, 'max_bin': 302, 'bagging_fraction': 0.8414752144259561, 'eature_fraction': 0.5193476729450877, 'min_gain_to_split': 0.3146427742972587, 'lambda_11': 0.10707261724119696, 'lambda_12': 0.9080971089939976}. Best is trial 41 with value: 6.425571722194169.
# [I 2024-09-06 17:02:24,510] Trial 42 finished with value: 7.11634165945777 and parameters: {'num_leaves': 51, 'min_data_in_leaf': 14, 'max_bin': 317, 'bagging_fraction': 0.8614179299737091, 'eature_fraction': 0.5082260172785336, 'min_gain_to_split': 0.5810671319882914, 'lambda_11': 0.10811157589111166, 'lambda_12': 0.7971472840992753}. Best is trial 41 with value: 6.425571722194169.
# Early stopping, best iteration is:
# [87]	train's l2: 34.1992	valid's l2: 79.2326
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [86]	train's l2: 26.6445	valid's l2: 70.5097
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [98]	train's l2: 27.8212	valid's l2: 78.9056
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:24,605] Trial 43 finished with value: 6.6286434184665515 and parameters: {'num_leaves': 65, 'min_data_in_leaf': 10, 'max_bin': 281, 'bagging_fraction': 0.841543395432821, 'eature_fraction': 0.48664709482014146, 'min_gain_to_split': 0.7515363686183039, 'lambda_11': 0.06904041889197296, 'lambda_12': 0.9737101985596872}. Best is trial 41 with value: 6.425571722194169.
# [I 2024-09-06 17:02:24,696] Trial 44 finished with value: 7.068324285933636 and parameters: {'num_leaves': 70, 'min_data_in_leaf': 10, 'max_bin': 282, 'bagging_fraction': 0.8408952288538659, 'eature_fraction': 0.45939658567050706, 'min_gain_to_split': 0.7685667942455285, 'lambda_11': 0.05064004233856951, 'lambda_12': 0.9407569258254933}. Best is trial 41 with value: 6.425571722194169.
# Early stopping, best iteration is:
# [87]	train's l2: 29.5786	valid's l2: 69.4483
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 30.0835	valid's l2: 77.3935
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:24,813] Trial 45 finished with value: 8.358030803532497 and parameters: {'num_leaves': 62, 'min_data_in_leaf': 7, 'max_bin': 301, 'bagging_fraction': 0.8561175289184819, 'eature_fraction': 0.4879793907722234, 'min_gain_to_split': 0.38058943507277954, 'lambda_11': 0.07222087213761355, 'lambda_12': 0.43807276429244474}. Best is trial 41 with value: 6.425571722194169.
# [I 2024-09-06 17:02:24,897] Trial 46 finished with value: 6.845181379398378 and parameters: {'num_leaves': 59, 'min_data_in_leaf': 13, 'max_bin': 291, 'bagging_fraction': 0.8382172553445366, 'eature_fraction': 0.4132426743195915, 'min_gain_to_split': 0.19498803933589282, 'lambda_11': 0.03517234708460067, 'lambda_12': 0.6906925436143864}. Best is trial 41 with value: 6.425571722194169.
# [I 2024-09-06 17:02:24,975] Trial 47 finished with value: 6.817723791475144 and parameters: {'num_leaves': 66, 'min_data_in_leaf': 10, 'max_bin': 276, 'bagging_fraction': 0.8114839877586295, 'eature_fraction': 0.46719816083791693, 'min_gain_to_split': 0.511520538411831, 'lambda_11': 0.10880183585057326, 'lambda_12': 0.9699474542077711}. Best is trial 41 with value: 6.425571722194169.
# Early stopping, best iteration is:
# [57]	train's l2: 33.5145	valid's l2: 104.83
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [80]	train's l2: 32.5641	valid's l2: 75.8149
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	train's l2: 29.4298	valid's l2: 73.1106
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:25,067] Trial 48 finished with value: 7.305774006788591 and parameters: {'num_leaves': 83, 'min_data_in_leaf': 18, 'max_bin': 324, 'bagging_fraction': 0.8527960583788559, 'eature_fraction': 0.4404443412243291, 'min_gain_to_split': 0.800935381273058, 'lambda_11': 0.18357589146406283, 'lambda_12': 0.30339298246503976}. Best is trial 41 with value: 6.425571722194169.
# [I 2024-09-06 17:02:25,190] Trial 49 finished with value: 7.921913692212597 and parameters: {'num_leaves': 97, 'min_data_in_leaf': 5, 'max_bin': 307, 'bagging_fraction': 0.8457775911406192, 'eature_fraction': 0.38507513635916724, 'min_gain_to_split': 0.16391321528154248, 'lambda_11': 0.08014865222389732, 'lambda_12': 0.6283205065459784}. Best is trial 41 with value: 6.425571722194169.
# Early stopping, best iteration is:
# [87]	train's l2: 32.9144	valid's l2: 81.0523
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 24.8634	valid's l2: 95.6798
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:25,305] Trial 50 finished with value: 6.569607242189081 and parameters: {'num_leaves': 72, 'min_data_in_leaf': 15, 'max_bin': 240, 'bagging_fraction': 0.8346232658390714, 'eature_fraction': 0.515611886559053, 'min_gain_to_split': 0.37220269104138687, 'lambda_11': 0.04754738899746929, 'lambda_12': 0.5393595809589488}. Best is trial 41 with value: 6.425571722194169.
# [I 2024-09-06 17:02:25,385] Trial 51 finished with value: 6.899382592467233 and parameters: {'num_leaves': 74, 'min_data_in_leaf': 15, 'max_bin': 241, 'bagging_fraction': 0.8331331830819317, 'eature_fraction': 0.48599030979942964, 'min_gain_to_split': 0.3469750147972617, 'lambda_11': 0.04616038456778279, 'lambda_12': 0.42395692211127045}. Best is trial 41 with value: 6.425571722194169.
# [I 2024-09-06 17:02:25,479] Trial 52 finished with value: 6.977436110840519 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 15, 'max_bin': 260, 'bagging_fraction': 0.8239399239950901, 'eature_fraction': 0.506184389362471, 'min_gain_to_split': 0.46709525708191496, 'lambda_11': 0.023047147681972868, 'lambda_12': 0.5841794636789067}. Best is trial 41 with value: 6.425571722194169.
# Early stopping, best iteration is:
# [102]	train's l2: 25.5034	valid's l2: 71.2041
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	train's l2: 30.5421	valid's l2: 75.1991
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [96]	train's l2: 28.008	valid's l2: 76.5315
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:25,582] Trial 53 finished with value: 6.424576487847991 and parameters: {'num_leaves': 65, 'min_data_in_leaf': 12, 'max_bin': 233, 'bagging_fraction': 0.8073720485328656, 'eature_fraction': 0.5122585424140601, 'min_gain_to_split': 0.2546332357110473, 'lambda_11': 0.03889430716570023, 'lambda_12': 0.7962342858285232}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:25,680] Trial 54 finished with value: 7.907943936054793 and parameters: {'num_leaves': 64, 'min_data_in_leaf': 9, 'max_bin': 232, 'bagging_fraction': 0.805899609327488, 'eature_fraction': 0.514841850315686, 'min_gain_to_split': 0.1304913141811405, 'lambda_11': 0.12144696125532006, 'lambda_12': 0.8666400528329428}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [88]	train's l2: 25.7457	valid's l2: 68.0884
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	train's l2: 24.6164	valid's l2: 94.8635
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 25.994	valid's l2: 79.096
# [I 2024-09-06 17:02:25,780] Trial 55 finished with value: 7.251284499589342 and parameters: {'num_leaves': 73, 'min_data_in_leaf': 12, 'max_bin': 236, 'bagging_fraction': 0.809729127951772, 'eature_fraction': 0.5621513669285595, 'min_gain_to_split': 0.2055959731490502, 'lambda_11': 0.06337123798070303, 'lambda_12': 0.7353249288982014}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:25,905] Trial 56 finished with value: 6.697319069694597 and parameters: {'num_leaves': 87, 'min_data_in_leaf': 11, 'max_bin': 213, 'bagging_fraction': 0.8298822191542088, 'eature_fraction': 0.5391571595729757, 'min_gain_to_split': 0.24420156950005928, 'lambda_11': 0.042241998682019416, 'lambda_12': 0.5326104209545534}. Best is trial 53 with value: 6.424576487847991.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [92]	train's l2: 22.7587	valid's l2: 71.1097
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:26,002] Trial 57 finished with value: 7.744934279302684 and parameters: {'num_leaves': 80, 'min_data_in_leaf': 8, 'max_bin': 211, 'bagging_fraction': 0.8300207126234967, 'eature_fraction': 0.5423442708682387, 'min_gain_to_split': 0.24394025110786394, 'lambda_11': 0.05358639595516085, 'lambda_12': 0.5295046569535699}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:26,094] Trial 58 finished with value: 6.896845311763206 and parameters: {'num_leaves': 69, 'min_data_in_leaf': 11, 'max_bin': 210, 'bagging_fraction': 0.8354948899627298, 'eature_fraction': 0.525470372910737, 'min_gain_to_split': 0.9767313501471322, 'lambda_11': 0.04293194738381407, 'lambda_12': 0.6647156556114346}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [73]	train's l2: 23.5597	valid's l2: 88.8176
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [100]	train's l2: 24.5858	valid's l2: 73.8442
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:26,215] Trial 59 finished with value: 7.703977846213697 and parameters: {'num_leaves': 86, 'min_data_in_leaf': 9, 'max_bin': 224, 'bagging_fraction': 0.8239067223406237, 'eature_fraction': 0.5181097160557242, 'min_gain_to_split': 0.5703511269883124, 'lambda_11': 0.03780204425543472, 'lambda_12': 0.30717251030589077}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:26,312] Trial 60 finished with value: 7.208063364749937 and parameters: {'num_leaves': 102, 'min_data_in_leaf': 17, 'max_bin': 251, 'bagging_fraction': 0.8428308605928538, 'eature_fraction': 0.5383975630752339, 'min_gain_to_split': 0.08109395095118162, 'lambda_11': 0.09224570956248421, 'lambda_12': 0.9997699942094197}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [102]	train's l2: 21.1621	valid's l2: 89.1942
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 28.696	valid's l2: 81.0822
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:26,418] Trial 61 finished with value: 6.944682226190064 and parameters: {'num_leaves': 91, 'min_data_in_leaf': 13, 'max_bin': 244, 'bagging_fraction': 0.8051429877690702, 'eature_fraction': 0.5538778762699361, 'min_gain_to_split': 0.4112070055854166, 'lambda_11': 0.06990414754655704, 'lambda_12': 0.7852548149543257}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:26,500] Trial 62 finished with value: 6.6126759977100384 and parameters: {'num_leaves': 76, 'min_data_in_leaf': 12, 'max_bin': 208, 'bagging_fraction': 0.8180508145048951, 'eature_fraction': 0.49891342171485276, 'min_gain_to_split': 0.28427989684362354, 'lambda_11': 0.15845530331615462, 'lambda_12': 0.5081786606437912}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:26,599] Trial 63 finished with value: 6.952458423046716 and parameters: {'num_leaves': 77, 'min_data_in_leaf': 14, 'max_bin': 200, 'bagging_fraction': 0.8206122943618209, 'eature_fraction': 0.5012243635611324, 'min_gain_to_split': 0.28283828984217385, 'lambda_11': 0.031768564454401384, 'lambda_12': 0.5200136306573361}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [83]	train's l2: 24.9287	valid's l2: 75.2909
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [64]	train's l2: 33.4767	valid's l2: 70.1357
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 26.8974	valid's l2: 75.7455
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:26,690] Trial 64 finished with value: 6.691490599991457 and parameters: {'num_leaves': 69, 'min_data_in_leaf': 12, 'max_bin': 226, 'bagging_fraction': 0.8289556977151529, 'eature_fraction': 0.4821922294541113, 'min_gain_to_split': 0.28999176978016966, 'lambda_11': 0.1531566345606963, 'lambda_12': 0.6163860185978327}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:26,776] Trial 65 finished with value: 6.579427031849438 and parameters: {'num_leaves': 71, 'min_data_in_leaf': 12, 'max_bin': 206, 'bagging_fraction': 0.8127922577197599, 'eature_fraction': 0.48223801051038273, 'min_gain_to_split': 0.8254521981198067, 'lambda_11': 0.16005878901826281, 'lambda_12': 0.8387161128201739}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:26,868] Trial 66 finished with value: 6.867024933015555 and parameters: {'num_leaves': 63, 'min_data_in_leaf': 10, 'max_bin': 207, 'bagging_fraction': 0.8106001013313736, 'eature_fraction': 0.4981428058637004, 'min_gain_to_split': 0.8168470230226983, 'lambda_11': 0.1740598526462298, 'lambda_12': 0.8427502823656358}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [79]	train's l2: 31.5799	valid's l2: 70.5819
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 31.3623	valid's l2: 68.8618
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 31.045	valid's l2: 74.2043
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:26,956] Trial 67 finished with value: 7.4481229349405105 and parameters: {'num_leaves': 57, 'min_data_in_leaf': 8, 'max_bin': 220, 'bagging_fraction': 0.8132973016789603, 'eature_fraction': 0.47152463180428744, 'min_gain_to_split': 0.5374446039579224, 'lambda_11': 0.12303441639687368, 'lambda_12': 0.7019413506976174}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:27,062] Trial 68 finished with value: 8.249562913335465 and parameters: {'num_leaves': 72, 'min_data_in_leaf': 6, 'max_bin': 259, 'bagging_fraction': 0.8054227220078158, 'eature_fraction': 0.5140197887559824, 'min_gain_to_split': 0.4552189117969559, 'lambda_11': 0.057553628455928284, 'lambda_12': 0.8536492547979646}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [87]	train's l2: 29.3151	valid's l2: 81.8758
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [109]	train's l2: 20.0612	valid's l2: 101.187
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [75]	train's l2: 33.7835	valid's l2: 72.9273
# [I 2024-09-06 17:02:27,153] Trial 69 finished with value: 6.913350755569311 and parameters: {'num_leaves': 50, 'min_data_in_leaf': 11, 'max_bin': 312, 'bagging_fraction': 0.8203948074711395, 'eature_fraction': 0.49292481120102827, 'min_gain_to_split': 0.7260601184088258, 'lambda_11': 0.09212606751886941, 'lambda_12': 0.3929128116339315}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:27,287] Trial 70 finished with value: 7.033829130905027 and parameters: {'num_leaves': 78, 'min_data_in_leaf': 13, 'max_bin': 204, 'bagging_fraction': 0.8385643113930444, 'eature_fraction': 0.5302348504285331, 'min_gain_to_split': 0.37886663042824786, 'lambda_11': 0.2710861525617839, 'lambda_12': 0.33729236347983793}. Best is trial 53 with value: 6.424576487847991.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [102]	train's l2: 23.7367	valid's l2: 76.737
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:27,379] Trial 71 finished with value: 6.4695153426547165 and parameters: {'num_leaves': 67, 'min_data_in_leaf': 12, 'max_bin': 226, 'bagging_fraction': 0.815542759307322, 'eature_fraction': 0.48388658715082733, 'min_gain_to_split': 0.3026343084258038, 'lambda_11': 0.13801017413262787, 'lambda_12': 0.6128693012416868}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:27,462] Trial 72 finished with value: 6.944637503704448 and parameters: {'num_leaves': 64, 'min_data_in_leaf': 14, 'max_bin': 219, 'bagging_fraction': 0.815621399433, 'eature_fraction': 0.4787733911959062, 'min_gain_to_split': 0.8449321158987029, 'lambda_11': 0.14028811480405234, 'lambda_12': 0.5917598056991423}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:27,546] Trial 73 finished with value: 6.460720617946996 and parameters: {'num_leaves': 60, 'min_data_in_leaf': 12, 'max_bin': 231, 'bagging_fraction': 0.825546347577326, 'eature_fraction': 0.5058883059889817, 'min_gain_to_split': 0.644772793893247, 'lambda_11': 0.11340942140287386, 'lambda_12': 0.4794904900849439}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [79]	train's l2: 31.7582	valid's l2: 65.3377
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 32.9834	valid's l2: 78.5043
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 27.4798	valid's l2: 67.217
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:27,620] Trial 74 finished with value: 7.025574651787097 and parameters: {'num_leaves': 74, 'min_data_in_leaf': 17, 'max_bin': 233, 'bagging_fraction': 0.8040372855223156, 'eature_fraction': 0.4896833594706527, 'min_gain_to_split': 0.14333090565134604, 'lambda_11': 0.17873030587881147, 'lambda_12': 0.7464712836152902}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:27,733] Trial 75 finished with value: 7.028654809374162 and parameters: {'num_leaves': 156, 'min_data_in_leaf': 10, 'max_bin': 245, 'bagging_fraction': 0.8348000171438107, 'eature_fraction': 0.4671742284336843, 'min_gain_to_split': 0.1917998150865117, 'lambda_11': 0.08414705283899582, 'lambda_12': 0.885783536731195}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [81]	train's l2: 33.2102	valid's l2: 75.4171
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [63]	train's l2: 31.3197	valid's l2: 75.315
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:27,830] Trial 76 finished with value: 6.445954096221655 and parameters: {'num_leaves': 66, 'min_data_in_leaf': 15, 'max_bin': 225, 'bagging_fraction': 0.8191262537688708, 'eature_fraction': 0.5018495947381548, 'min_gain_to_split': 0.44704572164541767, 'lambda_11': 0.2014003436829077, 'lambda_12': 0.48559653089021265}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:27,947] Trial 77 finished with value: 6.5877174933749085 and parameters: {'num_leaves': 82, 'min_data_in_leaf': 15, 'max_bin': 225, 'bagging_fraction': 0.8181023886886798, 'eature_fraction': 0.5050194644461595, 'min_gain_to_split': 0.3114088321930658, 'lambda_11': 0.2036642731029936, 'lambda_12': 0.4715556445052933}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [101]	train's l2: 25.9317	valid's l2: 67.5431
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [101]	train's l2: 24.9563	valid's l2: 70.3977
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:28,049] Trial 78 finished with value: 6.795564734588909 and parameters: {'num_leaves': 83, 'min_data_in_leaf': 15, 'max_bin': 226, 'bagging_fraction': 0.8084734998444513, 'eature_fraction': 0.5057966838634688, 'min_gain_to_split': 0.41981994419499696, 'lambda_11': 0.24401310025891984, 'lambda_12': 0.4603733476364213}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:28,136] Trial 79 finished with value: 7.220154368827715 and parameters: {'num_leaves': 60, 'min_data_in_leaf': 19, 'max_bin': 237, 'bagging_fraction': 0.8148918459300455, 'eature_fraction': 0.5270676092141537, 'min_gain_to_split': 0.3170993615899126, 'lambda_11': 0.20414366337140896, 'lambda_12': 0.16776825729899372}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [83]	train's l2: 26.7599	valid's l2: 73.5333
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [80]	train's l2: 30.5366	valid's l2: 82.3463
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	train's l2: 26.3868	valid's l2: 78.28
# [I 2024-09-06 17:02:28,247] Trial 80 finished with value: 7.1679874075558665 and parameters: {'num_leaves': 124, 'min_data_in_leaf': 16, 'max_bin': 231, 'bagging_fraction': 0.8266724203687087, 'eature_fraction': 0.54704338148089, 'min_gain_to_split': 0.372095963251792, 'lambda_11': 0.10608442461948496, 'lambda_12': 0.34715611623043796}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:28,338] Trial 81 finished with value: 6.73699596096081 and parameters: {'num_leaves': 68, 'min_data_in_leaf': 13, 'max_bin': 215, 'bagging_fraction': 0.8201070431679324, 'eature_fraction': 0.49565203401534, 'min_gain_to_split': 0.2198266741616576, 'lambda_11': 0.15679230250856818, 'lambda_12': 0.5104877447110208}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:28,440] Trial 82 finished with value: 7.1087016122165005 and parameters: {'num_leaves': 77, 'min_data_in_leaf': 14, 'max_bin': 222, 'bagging_fraction': 0.8173923338620852, 'eature_fraction': 0.5045771831246381, 'min_gain_to_split': 0.4798156438375578, 'lambda_11': 0.3250323227280233, 'lambda_12': 0.27540413767534966}. Best is trial 53 with value: 6.424576487847991.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 31.5758	valid's l2: 72.6757
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [90]	train's l2: 25.7983	valid's l2: 76.6119
# [I 2024-09-06 17:02:28,523] Trial 83 finished with value: 7.062832599492725 and parameters: {'num_leaves': 55, 'min_data_in_leaf': 17, 'max_bin': 216, 'bagging_fraction': 0.8004740370442931, 'eature_fraction': 0.5210840340540606, 'min_gain_to_split': 0.22778172462562973, 'lambda_11': 0.19554009003323927, 'lambda_12': 0.5865163072941615}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:28,616] Trial 84 finished with value: 6.483037190944725 and parameters: {'num_leaves': 71, 'min_data_in_leaf': 12, 'max_bin': 209, 'bagging_fraction': 0.8225254286935012, 'eature_fraction': 0.4774923387013658, 'min_gain_to_split': 0.29821097651618583, 'lambda_11': 0.13173369266959917, 'lambda_12': 0.6586277626768368}. Best is trial 53 with value: 6.424576487847991.
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 29.8773	valid's l2: 80.6904
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 31.414	valid's l2: 67.3574
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:28,709] Trial 85 finished with value: 6.74160151265633 and parameters: {'num_leaves': 93, 'min_data_in_leaf': 16, 'max_bin': 248, 'bagging_fraction': 0.8216350164731818, 'eature_fraction': 0.47709930387297433, 'min_gain_to_split': 0.6466147353933132, 'lambda_11': 0.12638318767517015, 'lambda_12': 0.6466824760513409}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:28,784] Trial 86 finished with value: 7.087901874675499 and parameters: {'num_leaves': 71, 'min_data_in_leaf': 14, 'max_bin': 228, 'bagging_fraction': 0.8126193711376222, 'eature_fraction': 0.44841017945921946, 'min_gain_to_split': 0.31068249069825016, 'lambda_11': 0.24707428645032498, 'lambda_12': 0.7607562383521382}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:28,874] Trial 87 finished with value: 6.930360253581664 and parameters: {'num_leaves': 62, 'min_data_in_leaf': 13, 'max_bin': 205, 'bagging_fraction': 0.8262118872564715, 'eature_fraction': 0.5106812778614844, 'min_gain_to_split': 0.5513505577275047, 'lambda_11': 0.1373382324657033, 'lambda_12': 0.4678433821082245}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# [79]	train's l2: 33.3334	valid's l2: 69.8713
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 32.3858	valid's l2: 79.572
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [84]	train's l2: 27.0166	valid's l2: 76.5459
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:02:28,956] Trial 88 finished with value: 6.90969330123292 and parameters: {'num_leaves': 81, 'min_data_in_leaf': 15, 'max_bin': 235, 'bagging_fraction': 0.8312170075225808, 'eature_fraction': 0.4694222967700346, 'min_gain_to_split': 0.2629868553110876, 'lambda_11': 0.3706321709410308, 'lambda_12': 0.38426660835124576}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:29,030] Trial 89 finished with value: 7.6708261105103706 and parameters: {'num_leaves': 66, 'min_data_in_leaf': 28, 'max_bin': 200, 'bagging_fraction': 0.8082259004067515, 'eature_fraction': 0.4826019458436025, 'min_gain_to_split': 0.3546412259090282, 'lambda_11': 0.2160514985532518, 'lambda_12': 0.21830001708837368}. Best is trial 53 with value: 6.424576487847991.
# [I 2024-09-06 17:02:29,115] Trial 90 finished with value: 6.836729804711714 and parameters: {'num_leaves': 60, 'min_data_in_leaf': 12, 'max_bin': 218, 'bagging_fraction': 0.8229532911678527, 'eature_fraction': 0.4650931169832012, 'min_gain_to_split': 0.4323081605040675, 'lambda_11': 0.2812520571957926, 'lambda_12': 0.6647994611226206}. Best is trial 53 with value: 6.424576487847991.
# Early stopping, best iteration is:
# ...
# [I 2024-09-06 17:05:16,916] Trial 1471 finished with value: 5.8615692038867655 and parameters: {'num_leaves': 58, 'min_data_in_leaf': 14, 'max_bin': 253, 'bagging_fraction': 0.8128997499773074, 'eature_fraction': 0.35041785743818016, 'min_gain_to_split': 0.05953756040802131, 'lambda_11': 0.014882061549872436, 'lambda_12': 0.06776022164610745}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [90]	train's l2: 27.8323	valid's l2: 68.3759
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [135]	train's l2: 38.5963	valid's l2: 58.1093
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:17,023] Trial 1472 finished with value: 5.766396222669382 and parameters: {'num_leaves': 50, 'min_data_in_leaf': 14, 'max_bin': 253, 'bagging_fraction': 0.8114810713088779, 'eature_fraction': 0.3503994308243931, 'min_gain_to_split': 0.06914828806640819, 'lambda_11': 0.015557156123090617, 'lambda_12': 0.061752035030141594}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:17,131] Trial 1473 finished with value: 5.701615373969855 and parameters: {'num_leaves': 52, 'min_data_in_leaf': 14, 'max_bin': 256, 'bagging_fraction': 0.8103743228748124, 'eature_fraction': 0.354770463524758, 'min_gain_to_split': 0.06134408626572096, 'lambda_11': 0.01527800808034245, 'lambda_12': 0.06523651582301153}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [113]	train's l2: 40.2283	valid's l2: 56.2019
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	train's l2: 40.1781	valid's l2: 56.7393
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:17,239] Trial 1474 finished with value: 5.755444553946889 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 14, 'max_bin': 255, 'bagging_fraction': 0.8107783416689738, 'eature_fraction': 0.3552130632927776, 'min_gain_to_split': 0.061173118211949144, 'lambda_11': 0.0157737876749719, 'lambda_12': 0.06558397852501706}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:17,347] Trial 1475 finished with value: 5.766405351455464 and parameters: {'num_leaves': 50, 'min_data_in_leaf': 14, 'max_bin': 250, 'bagging_fraction': 0.8078726178116353, 'eature_fraction': 0.3502144462374059, 'min_gain_to_split': 0.06584519709077478, 'lambda_11': 0.015204716483321662, 'lambda_12': 0.07157259863101675}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [113]	train's l2: 40.1583	valid's l2: 57.7999
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	train's l2: 40.2281	valid's l2: 56.2018
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:17,457] Trial 1476 finished with value: 5.753383602879854 and parameters: {'num_leaves': 54, 'min_data_in_leaf': 14, 'max_bin': 251, 'bagging_fraction': 0.8138937626464151, 'eature_fraction': 0.3503182216768321, 'min_gain_to_split': 0.05820609510832857, 'lambda_11': 0.015564472672430937, 'lambda_12': 0.061207551768069794}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:17,572] Trial 1477 finished with value: 5.751632766785511 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 13, 'max_bin': 257, 'bagging_fraction': 0.8105245546502735, 'eature_fraction': 0.3503747919926039, 'min_gain_to_split': 0.07133575127331546, 'lambda_11': 0.016108944645288503, 'lambda_12': 0.06756934279436932}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [113]	train's l2: 40.0077	valid's l2: 57.794
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [137]	train's l2: 38.395	valid's l2: 54.9032
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:17,679] Trial 1478 finished with value: 5.766405351455464 and parameters: {'num_leaves': 50, 'min_data_in_leaf': 14, 'max_bin': 250, 'bagging_fraction': 0.8149033393553899, 'eature_fraction': 0.35003060454758994, 'min_gain_to_split': 0.06266472465643916, 'lambda_11': 0.01636052143936688, 'lambda_12': 0.0601333159481682}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:17,780] Trial 1479 finished with value: 5.931598281077101 and parameters: {'num_leaves': 54, 'min_data_in_leaf': 13, 'max_bin': 255, 'bagging_fraction': 0.8138342840431902, 'eature_fraction': 0.35000945328596245, 'min_gain_to_split': 0.057806463052465666, 'lambda_11': 0.014498642404261882, 'lambda_12': 0.07364360143594291}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [113]	train's l2: 40.2281	valid's l2: 56.2018
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [135]	train's l2: 38.5586	valid's l2: 57.8851
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:17,892] Trial 1480 finished with value: 5.683973092081226 and parameters: {'num_leaves': 55, 'min_data_in_leaf': 14, 'max_bin': 249, 'bagging_fraction': 0.8087028959109326, 'eature_fraction': 0.35000581858838825, 'min_gain_to_split': 0.06972707741555588, 'lambda_11': 0.015745385002840222, 'lambda_12': 0.05478532355301963}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:18,014] Trial 1481 finished with value: 5.871500177072098 and parameters: {'num_leaves': 56, 'min_data_in_leaf': 13, 'max_bin': 251, 'bagging_fraction': 0.8062934814589354, 'eature_fraction': 0.35035308704067547, 'min_gain_to_split': 0.07288949044256242, 'lambda_11': 0.015169722072645801, 'lambda_12': 0.05626041743922261}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [113]	train's l2: 40.0371	valid's l2: 57.5007
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [137]	train's l2: 38.2949	valid's l2: 56.9398
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:18,129] Trial 1482 finished with value: 7.062841979864621 and parameters: {'num_leaves': 56, 'min_data_in_leaf': 14, 'max_bin': 248, 'bagging_fraction': 0.8078538332461368, 'eature_fraction': 0.35967123058409667, 'min_gain_to_split': 0.06909290585549499, 'lambda_11': 0.015512838930048912, 'lambda_12': 0.056208700860690165}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:18,239] Trial 1483 finished with value: 5.680054093797589 and parameters: {'num_leaves': 54, 'min_data_in_leaf': 14, 'max_bin': 248, 'bagging_fraction': 0.8142121354480246, 'eature_fraction': 0.3550224116975166, 'min_gain_to_split': 0.06609004036134625, 'lambda_11': 0.014591405492404761, 'lambda_12': 0.05409665808552176}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [79]	train's l2: 33.2027	valid's l2: 78.7827
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	train's l2: 40.0748	valid's l2: 57.4265
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:18,357] Trial 1484 finished with value: 5.751634384810588 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 13, 'max_bin': 248, 'bagging_fraction': 0.8150637292831385, 'eature_fraction': 0.35001381964393863, 'min_gain_to_split': 0.07460796208916119, 'lambda_11': 0.014725870360233394, 'lambda_12': 0.04904629808668221}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:18,455] Trial 1485 finished with value: 7.087094841124749 and parameters: {'num_leaves': 55, 'min_data_in_leaf': 14, 'max_bin': 248, 'bagging_fraction': 0.8155108714358584, 'eature_fraction': 0.3615532517855116, 'min_gain_to_split': 0.06815053346296389, 'lambda_11': 0.014591139769270203, 'lambda_12': 0.05374964644699142}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [137]	train's l2: 38.395	valid's l2: 54.9035
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 33.3304	valid's l2: 78.4508
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:18,565] Trial 1486 finished with value: 6.90142290093863 and parameters: {'num_leaves': 55, 'min_data_in_leaf': 14, 'max_bin': 249, 'bagging_fraction': 0.8158945375711881, 'eature_fraction': 0.3602525307560263, 'min_gain_to_split': 0.07473625557648084, 'lambda_11': 0.014511517903635595, 'lambda_12': 0.04290239722547833}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:18,682] Trial 1487 finished with value: 5.742829705993499 and parameters: {'num_leaves': 50, 'min_data_in_leaf': 13, 'max_bin': 247, 'bagging_fraction': 0.8127928555677583, 'eature_fraction': 0.35011150716486183, 'min_gain_to_split': 0.06614890674834834, 'lambda_11': 0.016786682094119168, 'lambda_12': 0.05303897277898585}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [79]	train's l2: 33.3627	valid's l2: 77.6562
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [134]	train's l2: 38.7263	valid's l2: 54.5399
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:18,795] Trial 1488 finished with value: 7.211534332061995 and parameters: {'num_leaves': 57, 'min_data_in_leaf': 14, 'max_bin': 245, 'bagging_fraction': 0.8152790699449131, 'eature_fraction': 0.36185258441323764, 'min_gain_to_split': 0.06747310208225063, 'lambda_11': 0.015280595871067072, 'lambda_12': 0.0577416561691555}. Best is trial 1464 with value: 5.638423889394876.
# [I 2024-09-06 17:05:18,906] Trial 1489 finished with value: 7.111243559820234 and parameters: {'num_leaves': 55, 'min_data_in_leaf': 14, 'max_bin': 252, 'bagging_fraction': 0.8093165118008671, 'eature_fraction': 0.35986132931294357, 'min_gain_to_split': 0.07211598917589952, 'lambda_11': 0.013959861974442109, 'lambda_12': 0.049440153935389516}. Best is trial 1464 with value: 5.638423889394876.
# Early stopping, best iteration is:
# [80]	train's l2: 33.2562	valid's l2: 80.6922
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [79]	train's l2: 33.2465	valid's l2: 79.5378
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:19,022] Trial 1490 finished with value: 5.624065021196403 and parameters: {'num_leaves': 52, 'min_data_in_leaf': 13, 'max_bin': 251, 'bagging_fraction': 0.813044118396068, 'eature_fraction': 0.355737833045621, 'min_gain_to_split': 0.06370948271210872, 'lambda_11': 0.01449259398867354, 'lambda_12': 0.07083112124030864}. Best is trial 1490 with value: 5.624065021196403.
# [I 2024-09-06 17:05:19,131] Trial 1491 finished with value: 6.647518192846493 and parameters: {'num_leaves': 50, 'min_data_in_leaf': 14, 'max_bin': 255, 'bagging_fraction': 0.8122334451009958, 'eature_fraction': 0.3604068216375691, 'min_gain_to_split': 0.05604926496765979, 'lambda_11': 0.016071634560383928, 'lambda_12': 0.0733561263042334}. Best is trial 1490 with value: 5.624065021196403.
# Early stopping, best iteration is:
# [134]	train's l2: 38.6699	valid's l2: 52.9218
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 33.4251	valid's l2: 71.748
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:19,242] Trial 1492 finished with value: 7.003894315448037 and parameters: {'num_leaves': 56, 'min_data_in_leaf': 14, 'max_bin': 250, 'bagging_fraction': 0.8094344098696427, 'eature_fraction': 0.429597061106423, 'min_gain_to_split': 0.055170955373298865, 'lambda_11': 0.016668536931204812, 'lambda_12': 0.07008993263867017}. Best is trial 1490 with value: 5.624065021196403.
# [I 2024-09-06 17:05:19,353] Trial 1493 finished with value: 7.149439386764084 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 13, 'max_bin': 252, 'bagging_fraction': 0.8157602316292999, 'eature_fraction': 0.36457290557282324, 'min_gain_to_split': 0.07690327064539115, 'lambda_11': 0.014786975334538384, 'lambda_12': 0.07174596422653678}. Best is trial 1490 with value: 5.624065021196403.
# Early stopping, best iteration is:
# [81]	train's l2: 32.9459	valid's l2: 77.4637
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [81]	train's l2: 32.8424	valid's l2: 79.9901
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:19,465] Trial 1494 finished with value: 5.652286824603949 and parameters: {'num_leaves': 55, 'min_data_in_leaf': 14, 'max_bin': 247, 'bagging_fraction': 0.8133732624383794, 'eature_fraction': 0.35596896148911833, 'min_gain_to_split': 0.06392283789844282, 'lambda_11': 0.01359351186499825, 'lambda_12': 0.07701123686257716}. Best is trial 1490 with value: 5.624065021196403.
# [I 2024-09-06 17:05:19,578] Trial 1495 finished with value: 7.193436624639457 and parameters: {'num_leaves': 52, 'min_data_in_leaf': 13, 'max_bin': 246, 'bagging_fraction': 0.8057525189778958, 'eature_fraction': 0.35964572582133414, 'min_gain_to_split': 0.07190416462020245, 'lambda_11': 0.014745472201880662, 'lambda_12': 0.07677362040773549}. Best is trial 1490 with value: 5.624065021196403.
# Early stopping, best iteration is:
# [113]	train's l2: 40.0192	valid's l2: 56.9184
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [87]	train's l2: 31.7822	valid's l2: 80.2628
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:19,690] Trial 1496 finished with value: 7.211534332061995 and parameters: {'num_leaves': 57, 'min_data_in_leaf': 14, 'max_bin': 245, 'bagging_fraction': 0.809266498358232, 'eature_fraction': 0.36591231619360226, 'min_gain_to_split': 0.06502328525219798, 'lambda_11': 0.01704609941919042, 'lambda_12': 0.07601766106969027}. Best is trial 1490 with value: 5.624065021196403.
# [I 2024-09-06 17:05:19,799] Trial 1497 finished with value: 5.767333301943684 and parameters: {'num_leaves': 53, 'min_data_in_leaf': 14, 'max_bin': 248, 'bagging_fraction': 0.8137882452771243, 'eature_fraction': 0.3557139078352944, 'min_gain_to_split': 0.06358249598361229, 'lambda_11': 0.014408178066949603, 'lambda_12': 0.06293980114565347}. Best is trial 1490 with value: 5.624065021196403.
# Early stopping, best iteration is:
# [80]	train's l2: 33.2562	valid's l2: 80.6922
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [113]	train's l2: 40.1465	valid's l2: 58.0199
#
# Training until validation scores don't improve for 50 rounds
# [I 2024-09-06 17:05:19,902] Trial 1498 finished with value: 7.002314945094619 and parameters: {'num_leaves': 56, 'min_data_in_leaf': 13, 'max_bin': 245, 'bagging_fraction': 0.8118206526829592, 'eature_fraction': 0.35980642447355404, 'min_gain_to_split': 0.07834525968546541, 'lambda_11': 0.014262602593064177, 'lambda_12': 0.07796207649599314}. Best is trial 1490 with value: 5.624065021196403.
# [I 2024-09-06 17:05:20,016] Trial 1499 finished with value: 6.87136710887643 and parameters: {'num_leaves': 51, 'min_data_in_leaf': 14, 'max_bin': 256, 'bagging_fraction': 0.8161079559069407, 'eature_fraction': 0.36524591134282974, 'min_gain_to_split': 0.06920831704815053, 'lambda_11': 0.015922885923050953, 'lambda_12': 0.06440366523149771}. Best is trial 1490 with value: 5.624065021196403.
# Early stopping, best iteration is:
# [87]	train's l2: 31.3507	valid's l2: 78.277
#
# Training until validation scores don't improve for 50 rounds
# Early stopping, best iteration is:
# [91]	train's l2: 31.8398	valid's l2: 74.1699

# %%
trial = study.best_trial
print(f'trial {trial.number}')
print('MAE best: %.2f'% trial.value)
display(trial.params)
# Out:
# trial 1490
# MAE best: 5.62
# {'num_leaves': 52,
#  'min_data_in_leaf': 13,
#  'max_bin': 251,
#  'bagging_fraction': 0.813044118396068,
#  'eature_fraction': 0.355737833045621,
#  'min_gain_to_split': 0.06370948271210872,
#  'lambda_11': 0.01449259398867354,
#  'lambda_12': 0.07083112124030864}

# %%
params_best = trial.params
params_best.update(params_base)
display(params_best)
# Out:
# {'num_leaves': 52,
#  'min_data_in_leaf': 13,
#  'max_bin': 251,
#  'bagging_fraction': 0.813044118396068,
#  'eature_fraction': 0.355737833045621,
#  'min_gain_to_split': 0.06370948271210872,
#  'lambda_11': 0.01449259398867354,
#  'lambda_12': 0.07083112124030864,
#  'objective': 'regression',
#  'metrics': 'mse',
#  'random_seed': 123,
#  'learnig_rate': 0.1,
#  'min_data_in_bin': 3,
#  'bagging_freq': 0,
#  'verbose': -1}

# %%
lgb_train = lgb.Dataset(x_tr, y_tr)
lgb_eval = lgb.Dataset(x_va, y_va, reference=lgb_train)

model = lgb.train(params_best,
                  lgb_train,
                  num_boost_round=3000,
                  valid_sets=[lgb_train, lgb_eval],
                  valid_names=['train', 'valid'],
                  callbacks=[lgb.early_stopping(100),
                             lgb.log_evaluation(300)])

y_va_pred = model.predict(x_va,
                          num_iteration=model.best_iteration)

score = mean_absolute_error(y_va, y_va_pred)
print(f'MAE valid: {score:.2f}')
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [52]	train's l2: 29.2798	valid's l2: 80.2149
# MAE valid: 7.32

# %%
pred_lgb = model.predict(test_data_open, num_iteration=model.best_iteration)

# %%
# テストデータから閉店日を取得
test_data2 = test_data.reset_index(inplace=False, drop=True)
test_data2
test_data2[test_data2['close']==1].index
# Out:
# Index([137, 274, 275, 276, 277], dtype='int64')

# %%
submit = pd.DataFrame({'datetime' : test_data.index, 'pred' : pred_lgb})

print(submit)

# 閉店時の予測値を0に置き換える
for i in test_data2[test_data2['close']==1].index:
    submit['pred'].iloc[i] = 0
    
# 予測値を描画
plt.plot(submit['pred'])

submit.columns = submit.iloc[0]
print(submit)
submit.to_csv('LGBM0906_3.csv', index=False)
# Out:
#       datetime       pred
# 0   2016-04-01  69.569370
# 1   2016-04-02  73.769551
# 2   2016-04-03  64.599264
# 3   2016-04-04  72.409509
# 4   2016-04-05  62.286259
# ..         ...        ...
# 360 2017-03-27  90.405421
# 361 2017-03-28  90.080096
# 362 2017-03-29  92.729092
# 363 2017-03-30  91.295586
# 364 2017-03-31  88.607387
#
# [365 rows x 2 columns]
# 0   2016-04-01 00:00:00   69.56937
# 0            2016-04-01  69.569370
# 1            2016-04-02  73.769551
# 2            2016-04-03  64.599264
# 3            2016-04-04  72.409509
# 4            2016-04-05  62.286259
# ..                  ...        ...
# 360          2017-03-27  90.405421
# 361          2017-03-28  90.080096
# 362          2017-03-29  92.729092
# 363          2017-03-30  91.295586
# 364          2017-03-31  88.607387
#
# [365 rows x 2 columns]
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_4803/2094988559.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit['pred'].iloc[i] = 0

# %%
### XGBoost ###

import xgboost as xgb
regressor = xgb.XGBRegressor()
regressor.fit(x_tr.values, y_tr.values)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
# 特徴量重要度（Feature Importances）
df_importance = pd.DataFrame(zip(x_tr.columns,
                                 regressor.feature_importances_),
                             columns=["Features","Importance"])
df_importance = df_importance.sort_values("Importance",
                                          ascending=False)
df_importance #確認
# Out:
#             Features  Importance
# 7          y_lag_365    0.284230
# 3              price    0.168052
# 4               year    0.122098
# 1           price_am    0.099351
# 13  price_pm_lag_365    0.078436
# 2           price_pm    0.067654
# 5              month    0.039875
# 11    price_pm_lag_1    0.025654
# 6            weekday    0.023308
# 8     price_am_lag_1    0.020810
# 10  price_am_lag_365    0.020621
# 9     price_am_lag_7    0.020612
# 12    price_pm_lag_7    0.015664
# 0             client    0.013634

# %%
# 予測
train_pred = regressor.predict(x_tr.values)
valid_pred = regressor.predict(x_va.values)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_percentage_error

# 精度指標（テストデータ）
print('RMSE:')
print(np.sqrt(mean_squared_error(y_test, valid_pred)))
print('MAE:')
print(mean_absolute_error(y_test, valid_pred))
print('MAPE:')
print(mean_absolute_percentage_error(y_test, valid_pred))
# Out:
# RMSE:
# 10.934731517431167
# MAE:
# 8.636187874780942
# MAPE:
# 0.19143021731858223

# %%
# グラフ化
fig, ax = plt.subplots()
ax.plot(y_train.index, y_train.values, label="actual(train dataset)")
ax.plot(y_test.index, y_test.values, label="actual(test dataset)")
ax.plot(y_train.index, train_pred, linestyle="dotted", lw=2,color="m")
ax.plot(y_test.index, test_pred, label="XGBoost", linestyle="dotted", lw=2, color="m") 
plt.legend()

# %%
pred_xgb = regressor.predict(test_data_open.values)

submit_xgb = pd.DataFrame({'datetime' : test_data.index, 'pred' : pred_xgb})

# 閉店時の予測値を0に置き換える
for i in test_data2[test_data2['close']==1].index:
    submit_xgb['pred'].iloc[i] = 0

submit_xgb
# Out:
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   submit_xgb['pred'].iloc[i] = 0
# /var/folders/55/p_rc8dfn457_yr0748h20c4r0000gn/T/ipykernel_1215/3180076692.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submit_xgb['pred'].iloc[i] = 0
#       datetime       pred
# 0   2016-04-01  63.198486
# 1   2016-04-02  75.893250
# 2   2016-04-03  55.166782
# 3   2016-04-04  62.232346
# 4   2016-04-05  72.111298
# ..         ...        ...
# 360 2017-03-27  70.372025
# 361 2017-03-28  71.345116
# 362 2017-03-29  81.478096
# 363 2017-03-30  90.237473
# 364 2017-03-31  67.121292
#
# [365 rows x 2 columns]

# %%
# 平均をとってアンサンブル
submit_ensemble = pd.DataFrame({'datetime' : test_data.index, 'pred' : ((pred_xgb) + (pred_lgb)) / 2})
submit_ensemble.columns = submit.iloc[0]

# %%
submit_ensemble
# Out:
# 0   2016-04-01 00:00:00  66.407773
# 0            2016-04-01  64.803130
# 1            2016-04-02  71.582382
# 2            2016-04-03  60.866888
# 3            2016-04-04  67.772229
# 4            2016-04-05  66.055382
# ..                  ...        ...
# 360          2017-03-27  74.048084
# 361          2017-03-28  74.534630
# 362          2017-03-29  80.658171
# 363          2017-03-30  87.388396
# 364          2017-03-31  72.343784
#
# [365 rows x 2 columns]

# %%
submit_ensemble.to_csv('ensemble_0903_1.csv', index=False)
